# %% [markdown]
# # RAG with Vector Database and Reranking on the OrchestrAI Synthetic Enterprise Corpus
#
# This notebook extends the vector-database RAG pipeline with a reranking stage while preserving the overall retrieval and generation logic.
#
# The goal is to evaluate the effect of reranking in isolation. Compared with the original `rag_vectordb` notebook, the main additions are:
# - richer document processing with **Docling**
# - tokenizer-aware chunking with **HybridChunker**
# - persistent storage in **Milvus**
# - a **cross-encoder reranker** placed after retrieval
# - explicit source metadata for cleaner citations and inspection
#
# This setup is useful for fair comparison because indexing, prompting, and generation remain broadly the same, while the retrieved candidate set is refined before it is passed to the LLM.
#
# **Outputs and IDs:** Logged as `implementation="reranker"` with scenario IDs `r1`–`r5` to `data/results/experimental/hpc_results.csv`. Retrieval uses **`retriever_top_k=20`** candidates, cross-encoder reranking to **`reranker_top_k=10`**, so the LLM receives **10** documents (aligned with other pipelines). Each run clears only previous `reranker` rows before saving. See `README.md` for evaluation.

# %% [markdown]
# ## What changes compared with the other notebooks?
#
# ### `rag_basic`
# - direct DOCX conversion
# - simpler splitting and indexing
# - in-memory retrieval
# - no persistent vector store
#
# ### `rag_vectordb`
# - richer conversion and chunking
# - persistent retrieval with Milvus
# - improved source metadata handling
#
# ### `rag_reranker`
# - keeps the same vector-database backbone as `rag_vectordb`
# - retrieves a larger candidate set first
# - reranks those candidates with a cross-encoder
# - passes only the reranked top documents to the prompt builder
#
# In other words, this notebook is designed to test whether reranking improves answer quality beyond dense retrieval alone.

# %% [markdown]
# ## Environment requirements
#
# This notebook assumes:
# - Python **3.12** in the project virtual environment and `requirements.txt`
# - vLLM services are running and reachable from this HPC job/session
# - `/nvme/scratch/cy26nk2/llm.env` and `/nvme/scratch/cy26nk2/embd.env` exist with valid API keys, URLs, and model names
# - Milvus is available in this environment (the notebook uses a file-backed URI under `notebooks-hpc/`)
# - the OrchestrAI corpus under **`data/dummy_data/`** (`PROJECT_ROOT / "data" / "dummy_data"`)
# - the package `sentence-transformers` is installed for the reranker
# - the first code cell prepends **`src/`** to `sys.path` for `results_logger`
#
# Run the optional install cell once if packages are missing.

# %% [markdown]
# ## Imports and runtime checks

# %%
import sys
import warnings
import time
from pathlib import Path


PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks-hpc" else Path.cwd()
SRC_DIR = PROJECT_ROOT / "src"

if str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

warnings.filterwarnings("ignore")

print("Python:", sys.executable)

from dotenv import dotenv_values
llm_config = dotenv_values('/nvme/scratch/cy26nk2/llm.env')
embd_config = dotenv_values('/nvme/scratch/cy26nk2/embd.env')
print("LLM model loaded:", llm_config.get("MODEL_NAME", "<missing>"))
print("Embedder model loaded:", embd_config.get("MODEL_NAME", "<missing>"))

from results_logger import save_result_row, clear_results_for_implementation

RESULTS_CSV = PROJECT_ROOT / "data" / "results" / "experimental" / "hpc_results.csv"
# Start this implementation's results from a clean slate.
clear_results_for_implementation("reranker", results_csv=RESULTS_CSV)

from haystack import Pipeline
from haystack.dataclasses import ChatMessage
from haystack.components.builders import ChatPromptBuilder
from haystack.components.writers import DocumentWriter
from haystack.components.preprocessors import DocumentSplitter
from haystack.components.rankers import SentenceTransformersSimilarityRanker

from milvus_haystack import MilvusDocumentStore
from milvus_haystack.milvus_embedding_retriever import MilvusEmbeddingRetriever

from haystack.components.embedders import OpenAIDocumentEmbedder, OpenAITextEmbedder
from haystack.components.generators.chat import OpenAIChatGenerator
from haystack.utils import Secret

from haystack_integrations.components.converters.docling import DoclingConverter
from docling.chunking import HybridChunker

print("Imports work")
# Out:
# Python: /nvme/h/cy26nk2/.conda/envs/notebookEnv/bin/python3.14
# LLM model loaded: meta-llama/Llama-3.1-8B-Instruct
# Embedder model loaded: BAAI/bge-m3
# Cleared existing rows for implementation='reranker'
# Imports work

# %% [markdown]
# ## Connect to Milvus
#
# This notebook uses a file-backed Milvus URI for local persistence in the project workspace.
#
# This keeps indexing reproducible across reruns in HPC sessions and aligned with the other Milvus notebooks.

# %%
notebooks_dir = PROJECT_ROOT / "notebooks-hpc"
if not notebooks_dir.exists():
    # Handles sessions where PROJECT_ROOT is already the notebooks-hpc folder.
    notebooks_dir = PROJECT_ROOT

db_path = str((notebooks_dir / "rag_reranker.db").resolve())
print("Milvus URI:", db_path)

# If this kernel already opened a Milvus connection, disconnect before reconnecting.
try:
    from pymilvus import connections
    connections.disconnect("default")
except Exception:
    pass

try:
    document_store = MilvusDocumentStore(
        connection_args={"uri": db_path},
        drop_old=False,
        enable_dynamic_field=False,
    )
except Exception as exc:
    msg = str(exc)
    if "not exists" in msg:
        raise RuntimeError(
            f"Milvus DB directory does not exist for path: {db_path}. Check PROJECT_ROOT and rerun."
        ) from exc
    if "Open local milvus failed" in msg or "DataDirLockedError" in repr(exc):
        raise RuntimeError(
            f"Shared Milvus DB is locked: {db_path}. Stop the other notebook/kernel using this DB, then rerun this cell."
        ) from exc
    raise

print("Milvus ready")
# Out:
# Milvus URI: /nvme/h/cy26nk2/Thesis/notebooks-hpc/rag_reranker.db
# Milvus ready

# %% [markdown]
# ## Load the OrchestrAI dataset
#
# The corpus is organized by department under **`data/dummy_data/`**; all `.docx` files are loaded recursively.
#
# Each file is later converted, chunked, enriched with metadata, embedded, and written to Milvus.

# %%
DOCUMENTS_DIR = PROJECT_ROOT / "data" / "dummy_data"
FILES = [str(f.resolve()) for f in DOCUMENTS_DIR.rglob("*.docx")]

print("Files found:", len(FILES))
for f in FILES[:10]:
    print("-", Path(f).name)
# Out:
# Files found: 54
# - VAL-SALES-002_Webinar_Launch_Brief_refreshed.docx
# - VAL-SALES-005_Discount_Exception_Policy_refreshed.docx
# - VAL-SALES-001_Lead_Routing_Rules_refreshed.docx
# - VAL-SALES-004_CRM_Field_Governance_Note_refreshed.docx
# - VAL-SALES-003_Campaign_Approval_Workflow_refreshed.docx
# - VAL-LOG-005_Reverse_Logistics_Routing_Memo.docx
# - VAL-LOG-004_Regional_Delivery_SLA_Matrix.docx
# - VAL-LOG-001_Carrier_Delay_Escalation_Notice.docx
# - VAL-LOG-002_Warehouse_Receiving_Checklist.docx
# - VAL-LOG-003_Damaged_Goods_Handling_SOP.docx

# %% [markdown]
# ## Indexing strategy
#
# To keep retrieval reliable and source-aware, the indexing flow is:
#
# 1. Convert each file with `DoclingConverter`
# 2. Attach explicit source metadata such as `file_name`, `file_path`, and `department`
# 3. Apply an additional `DocumentSplitter` before embedding
# 4. Remove metadata fields that Milvus cannot store cleanly
# 5. Generate embeddings with vLLM-served embedder
# 6. Write the embedded chunks to Milvus
#
# This file-by-file indexing approach also makes it easier to inspect retrieved chunks and avoid vague `unknown source` outputs during answer generation.

# %%
OLLAMA_EMBED_MODEL = "mxbai-embed-large"
HF_TOKENIZER_ID = "mixedbread-ai/mxbai-embed-large-v1"

converter = DoclingConverter(
    chunker=HybridChunker(
        tokenizer=HF_TOKENIZER_ID,
        max_tokens=300,
    )
)

splitter = DocumentSplitter(
    split_by="word",
    split_length=80,
    split_overlap=20
)

doc_embedder = OpenAIDocumentEmbedder(
    api_key=Secret.from_token(embd_config["VLLM_API_KEY"]),
    api_base_url=f"{embd_config['VLLM_EMBD_URL']}/v1",
    model=embd_config["MODEL_NAME"],
)

writer = DocumentWriter(document_store=document_store)

def normalize_meta(meta):
    cleaned = {}
    for key, value in (meta or {}).items():
        if key == "_split_overlap":
            continue
        if isinstance(value, (str, int, float, bool)) or value is None:
            cleaned[key] = value
        else:
            cleaned[key] = str(value)
    return cleaned

stored_chunks = 0
indexing_start = time.perf_counter()

for i, path in enumerate(FILES, 1):
    print(f"[{i}/{len(FILES)}] Indexing {Path(path).name}")

    converted = converter.run(paths=[path])["documents"]

    for doc in converted:
        meta = normalize_meta(doc.meta)
        meta["file_path"] = path
        meta["file_name"] = Path(path).name
        meta["department"] = Path(path).parent.name
        doc.meta = meta

    split_docs = splitter.run(documents=converted)["documents"]

    for doc in split_docs:
        meta = normalize_meta(doc.meta)
        meta["file_path"] = path
        meta["file_name"] = Path(path).name
        meta["department"] = Path(path).parent.name
        doc.meta = meta

    embedded_docs = doc_embedder.run(documents=split_docs)["documents"]
    writer.run(documents=embedded_docs)

    stored_chunks += len(embedded_docs)

indexing_time_s = round(time.perf_counter() - indexing_start, 4)

print("Indexing completed.")
print("Stored chunks in Milvus:", stored_chunks)
print("Document store count:", document_store.count_documents())
print("Indexing time (s):", indexing_time_s)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [1/54] Indexing VAL-SALES-002_Webinar_Launch_Brief_refreshed.docx
# Calculating embeddings: 1it [00:00,  1.19it/s]
# [2/54] Indexing VAL-SALES-005_Discount_Exception_Policy_refreshed.docx
# Calculating embeddings: 1it [00:00, 29.53it/s]
# [3/54] Indexing VAL-SALES-001_Lead_Routing_Rules_refreshed.docx
# Calculating embeddings: 1it [00:00, 26.91it/s]
# [4/54] Indexing VAL-SALES-004_CRM_Field_Governance_Note_refreshed.docx
# Calculating embeddings: 1it [00:00, 29.54it/s]
# [5/54] Indexing VAL-SALES-003_Campaign_Approval_Workflow_refreshed.docx
# Calculating embeddings: 1it [00:00, 29.28it/s]
# [6/54] Indexing VAL-LOG-005_Reverse_Logistics_Routing_Memo.docx
# Calculating embeddings: 1it [00:00, 18.56it/s]
# [7/54] Indexing VAL-LOG-004_Regional_Delivery_SLA_Matrix.docx
# Calculating embeddings: 1it [00:00, 18.52it/s]
# [8/54] Indexing VAL-LOG-001_Carrier_Delay_Escalation_Notice.docx
# Calculating embeddings: 1it [00:00, 19.89it/s]
# [9/54] Indexing VAL-LOG-002_Warehouse_Receiving_Checklist.docx
# [transformers] Token indices sequence length is longer than the specified maximum sequence length for this model (897 > 512). Running this sequence through the model will result in indexing errors
# Calculating embeddings: 1it [00:00, 11.70it/s]
# [10/54] Indexing VAL-LOG-003_Damaged_Goods_Handling_SOP.docx
# Calculating embeddings: 1it [00:00, 17.41it/s]
# [11/54] Indexing VAL-HR-003_Recognition_Program_Criteria.docx
# Calculating embeddings: 1it [00:00, 32.27it/s]
# [12/54] Indexing VAL-HR-005_Meeting_Room_Usage_Update.docx
# Calculating embeddings: 1it [00:00, 29.30it/s]
# [13/54] Indexing VAL-HR-004_Desk_Move_Notice.docx
# Calculating embeddings: 1it [00:00, 40.49it/s]
# [14/54] Indexing VAL-HR-002_Leave_Request_Policy_Update.docx
# Calculating embeddings: 1it [00:00, 29.51it/s]
# [15/54] Indexing VAL-HR-001_Day_One_Onboarding_Checklist.docx
# Calculating embeddings: 1it [00:00, 24.64it/s]
# [16/54] Indexing VAL-PROD-001_Launch_Readiness_Checklist.docx
# Calculating embeddings: 1it [00:00, 18.46it/s]
# [17/54] Indexing VAL-PROD-002_Change_Request_Workflow.docx
# Calculating embeddings: 1it [00:00, 24.91it/s]
# [18/54] Indexing VAL-PROD-003_Release_Calendar_Update.docx
# Calculating embeddings: 1it [00:00, 29.05it/s]
# [19/54] Indexing VAL-PROD-004_Dependency_Risk_Register_Summary.docx
# Calculating embeddings: 1it [00:00, 25.09it/s]
# [20/54] Indexing VAL-PROD-005_Sprint_Review_Brief.docx
# Calculating embeddings: 1it [00:00, 30.06it/s]
# [21/54] Indexing VAL-ENG-004_Incident_RCA_Event_Processor_Timeout.docx
# Calculating embeddings: 1it [00:00, 14.98it/s]
# [22/54] Indexing VAL-ENG-001_Release_Freeze_Notice.docx
# Calculating embeddings: 1it [00:00, 22.58it/s]
# [23/54] Indexing VAL-ENG-003_API_Deprecation_Notice.docx
# Calculating embeddings: 1it [00:00, 19.69it/s]
# [24/54] Indexing VAL-ENG-005_Environment_Access_Rules.docx
# Calculating embeddings: 1it [00:00, 15.02it/s]
# [25/54] Indexing VAL-ENG-002_Deployment_Readiness_Checklist.docx
# Calculating embeddings: 1it [00:00, 17.80it/s]
# [26/54] Indexing VAL-CS-001_Severity_Matrix.docx
# Calculating embeddings: 1it [00:00, 21.52it/s]
# [27/54] Indexing VAL-CS-005_Knowledge_Base_Update_Memo.docx
# Calculating embeddings: 1it [00:00, 27.38it/s]
# [28/54] Indexing VAL-CS-004_Renewal_Risk_Signals_Brief.docx
# Calculating embeddings: 1it [00:00, 22.67it/s]
# [29/54] Indexing VAL-CS-003_Escalation_Handoff_Note.docx
# Calculating embeddings: 1it [00:00, 26.72it/s]
# [30/54] Indexing VAL-CS-002_New_Customer_Onboarding_Timeline.docx
# Calculating embeddings: 1it [00:00, 23.59it/s]
# [31/54] Indexing VAL-IT-003_VPN_Outage_Bulletin.docx
# Calculating embeddings: 1it [00:00, 18.94it/s]
# [32/54] Indexing VAL-IT-002_MFA_Enrollment_Guide.docx
# Calculating embeddings: 1it [00:00, 17.51it/s]
# [33/54] Indexing VAL-IT-004_Service_Desk_Priority_Matrix.docx
# Calculating embeddings: 1it [00:00, 17.58it/s]
# [34/54] Indexing VAL-IT-005_Password_Reset_Escalation_SOP.docx
# Calculating embeddings: 1it [00:00, 15.10it/s]
# [35/54] Indexing VAL-IT-001_Laptop_Provisioning_FAQ.docx
# Calculating embeddings: 1it [00:00, 16.45it/s]
# [36/54] Indexing VAL-SEC-005_Third_Party_Access_Approval_Standard.docx
# Calculating embeddings: 1it [00:00, 16.44it/s]
# [37/54] Indexing VAL-SEC-004_Data_Retention_Notice.docx
# Calculating embeddings: 1it [00:00, 15.72it/s]
# [38/54] Indexing VAL-SEC-002_Privileged_Access_Review_Memo.docx
# Calculating embeddings: 1it [00:00, 21.31it/s]
# [39/54] Indexing VAL-SEC-001_Phishing_Alert_Bulletin.docx
# Calculating embeddings: 1it [00:00, 20.00it/s]
# [40/54] Indexing VAL-SEC-003_Patch_Compliance_Reminder.docx
# Calculating embeddings: 1it [00:00, 23.33it/s]
# [41/54] Indexing TEAMQA-FIN-001_OrchestrAI_Finance_and_Procurement_Handbook.docx
# Calculating embeddings: 1it [00:00,  8.55it/s]
# [42/54] Indexing TEAMQA-SALES-001_OrchestrAI_Sales_and_Solutions_Handbook.docx
# Calculating embeddings: 1it [00:00,  8.56it/s]
# [43/54] Indexing TEAMQA-HR-001_OrchestrAI_HR_and_People_Operations_Handbook.docx
# Calculating embeddings: 1it [00:00,  8.35it/s]
# [44/54] Indexing TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx
# Calculating embeddings: 2it [00:00, 13.54it/s]
# [45/54] Indexing TEAMQA-ENG-001_OrchestrAI_Engineering_Platform_and_Edge_Systems_Handbook.docx
# Calculating embeddings: 1it [00:00,  7.98it/s]
# [46/54] Indexing TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx
# Calculating embeddings: 1it [00:00,  8.42it/s]
# [47/54] Indexing TEAMQA-SEC-001_OrchestrAI_Cybersecurity_Access_and_Compliance_Handbook.docx
# Calculating embeddings: 1it [00:00,  9.33it/s]
# [48/54] Indexing TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx
# Calculating embeddings: 1it [00:00,  9.10it/s]
# [49/54] Indexing TEAMQA-PROD-001_OrchestrAI_Product_and_Program_Management_Handbook.docx
# Calculating embeddings: 1it [00:00,  8.00it/s]
# [50/54] Indexing VAL-FIN-003_Vendor_Onboarding_Requirements.docx
# Calculating embeddings: 1it [00:00, 29.36it/s]
# [51/54] Indexing VAL-FIN-004_Month_End_Close_Reminder.docx
# Calculating embeddings: 1it [00:00, 32.43it/s]
# [52/54] Indexing VAL-FIN-005_Emergency_Procurement_Exception_Memo.docx
# Calculating embeddings: 1it [00:00, 29.48it/s]
# [53/54] Indexing VAL-FIN-002_Expense_Reimbursement_FAQ.docx
# Calculating embeddings: 1it [00:00, 32.90it/s]
# [54/54] Indexing VAL-FIN-001_Purchase_Order_Approval_Matrix.docx
# Calculating embeddings: 1it [00:00, 24.86it/s]
# Indexing completed.
# Stored chunks in Milvus: 654
# Document store count: 654
# Indexing time (s): 14.101
# [2/54] Indexing VAL-SALES-004_CRM_Field_Governance_Note_refreshed.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.36it/s]
# [3/54] Indexing VAL-SALES-005_Discount_Exception_Policy_refreshed.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.31it/s]
# [4/54] Indexing VAL-SALES-001_Lead_Routing_Rules_refreshed.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.21it/s]
# [5/54] Indexing VAL-SALES-002_Webinar_Launch_Brief_refreshed.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.88it/s]
# [6/54] Indexing VAL-SEC-003_Patch_Compliance_Reminder.docx
# [transformers] Token indices sequence length is longer than the specified maximum sequence length for this model (589 > 512). Running this sequence through the model will result in indexing errors
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.87it/s]
# [7/54] Indexing VAL-SEC-004_Data_Retention_Notice.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.03s/it]
# [8/54] Indexing VAL-SEC-005_Third_Party_Access_Approval_Standard.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# [9/54] Indexing VAL-SEC-002_Privileged_Access_Review_Memo.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.44it/s]
# [10/54] Indexing VAL-SEC-001_Phishing_Alert_Bulletin.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.71it/s]
# [11/54] Indexing VAL-IT-002_MFA_Enrollment_Guide.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.30it/s]
# [12/54] Indexing VAL-IT-005_Password_Reset_Escalation_SOP.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# [13/54] Indexing VAL-IT-001_Laptop_Provisioning_FAQ.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.02s/it]
# [14/54] Indexing VAL-IT-003_VPN_Outage_Bulletin.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.41it/s]
# [15/54] Indexing VAL-IT-004_Service_Desk_Priority_Matrix.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
# [16/54] Indexing VAL-PROD-001_Launch_Readiness_Checklist.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
# [17/54] Indexing VAL-PROD-005_Sprint_Review_Brief.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.60it/s]
# [18/54] Indexing VAL-PROD-003_Release_Calendar_Update.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.32it/s]
# [19/54] Indexing VAL-PROD-004_Dependency_Risk_Register_Summary.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# [20/54] Indexing VAL-PROD-002_Change_Request_Workflow.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# [21/54] Indexing VAL-CS-002_New_Customer_Onboarding_Timeline.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.89it/s]
# [22/54] Indexing VAL-CS-005_Knowledge_Base_Update_Memo.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# [23/54] Indexing VAL-CS-004_Renewal_Risk_Signals_Brief.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.42it/s]
# [24/54] Indexing VAL-CS-003_Escalation_Handoff_Note.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.18it/s]
# [25/54] Indexing VAL-CS-001_Severity_Matrix.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.85it/s]
# [26/54] Indexing VAL-HR-002_Leave_Request_Policy_Update.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.21it/s]
# [27/54] Indexing VAL-HR-005_Meeting_Room_Usage_Update.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.41it/s]
# [28/54] Indexing VAL-HR-004_Desk_Move_Notice.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.85it/s]
# [29/54] Indexing VAL-HR-003_Recognition_Program_Criteria.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  5.12it/s]
# [30/54] Indexing VAL-HR-001_Day_One_Onboarding_Checklist.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]
# [31/54] Indexing VAL-FIN-002_Expense_Reimbursement_FAQ.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.56it/s]
# [32/54] Indexing VAL-FIN-001_Purchase_Order_Approval_Matrix.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# [33/54] Indexing VAL-FIN-005_Emergency_Procurement_Exception_Memo.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.35it/s]
# [34/54] Indexing VAL-FIN-004_Month_End_Close_Reminder.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.25it/s]
# [35/54] Indexing VAL-FIN-003_Vendor_Onboarding_Requirements.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.04it/s]
# [36/54] Indexing VAL-LOG-002_Warehouse_Receiving_Checklist.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# [37/54] Indexing VAL-LOG-003_Damaged_Goods_Handling_SOP.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
# [38/54] Indexing VAL-LOG-005_Reverse_Logistics_Routing_Memo.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# [39/54] Indexing VAL-LOG-004_Regional_Delivery_SLA_Matrix.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.31it/s]
# [40/54] Indexing VAL-LOG-001_Carrier_Delay_Escalation_Notice.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]
# [41/54] Indexing VAL-ENG-001_Release_Freeze_Notice.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.90it/s]
# [42/54] Indexing VAL-ENG-005_Environment_Access_Rules.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
# [43/54] Indexing VAL-ENG-003_API_Deprecation_Notice.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.57it/s]
# [44/54] Indexing VAL-ENG-004_Incident_RCA_Event_Processor_Timeout.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# [45/54] Indexing VAL-ENG-002_Deployment_Readiness_Checklist.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.28it/s]
# [46/54] Indexing TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.96s/it]
# [47/54] Indexing TEAMQA-ENG-001_OrchestrAI_Engineering_Platform_and_Edge_Systems_Handbook.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.91s/it]
# [48/54] Indexing TEAMQA-SALES-001_OrchestrAI_Sales_and_Solutions_Handbook.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.94s/it]
# [49/54] Indexing TEAMQA-HR-001_OrchestrAI_HR_and_People_Operations_Handbook.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.84s/it]
# [50/54] Indexing TEAMQA-SEC-001_OrchestrAI_Cybersecurity_Access_and_Compliance_Handbook.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.59s/it]
# [51/54] Indexing TEAMQA-FIN-001_OrchestrAI_Finance_and_Procurement_Handbook.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.82s/it]
# [52/54] Indexing TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.75s/it]
# [53/54] Indexing TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx
# Calculating embeddings: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# [54/54] Indexing TEAMQA-PROD-001_OrchestrAI_Product_and_Program_Management_Handbook.docx
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  2.00s/it]
# Indexing completed.
# Stored chunks in Milvus: 654
# Document store count: 654
# Indexing time (s): 57.6895

# %% [markdown]
# ## Build the reranking RAG pipeline
#
# The answer-generation logic stays aligned with the earlier notebooks:
# - use only the retrieved context
# - avoid inventing missing information
# - cite source filenames when possible
#
# The main architectural difference is the added reranking step:
#
# `text_embedder -> retriever -> reranker -> prompt_builder -> llm`
#
# This keeps the experiment fair: the pipeline still uses the same corpus, vector store, and generator, but now refines retrieved candidates before prompting the LLM.

# %%
template = [
    ChatMessage.from_user(
        """
Respond to the User Query using only the provided Context.

General Guidelines:
- Use only the provided context.
- If the answer is not found in the context, say so clearly.
- Do not make up facts, document sections, pages, or citations.
- If the answer comes from multiple documents, cite all relevant documents.
- Respond in the same language as the user’s query.
- Do not use emojis.
- Be professional and concise.
- Do not write a conclusion or follow-up unless the user asks for it.
- If the context contains a direct policy rule, exception, SLA, or escalation instruction, state it directly and do not hedge.
- Prefer the most specific procedural source over broader handbook summaries when both are present.
- If the retrieved context does not explicitly contain the rule, exception, owner, or next step needed to answer the question, say that the retrieved context is insufficient instead of inferring or guessing.
- Do not mention system names, tools, workflows, or teams unless they are explicitly present in the retrieved context.

Citation Rules:
- For every important claim, cite the source document filename.
- If available in the retrieved context, also mention the document ID or department.
- Do not mention source chapter, section, or page unless they are explicitly present in the retrieved context.

Context:
{% for document in documents %}
[Source: {{ document.meta.get("file_name", document.meta.get("file_path", "unknown source")) }}]
{{ document.content }}

{% endfor %}

Question: {{question}}
Answer:
"""
    )
]

RERANK_MODEL = "cross-encoder/ms-marco-MiniLM-L-6-v2"

text_embedder = OpenAITextEmbedder(
    api_key=Secret.from_token(embd_config["VLLM_API_KEY"]),
    api_base_url=f"{embd_config['VLLM_EMBD_URL']}/v1",
    model=embd_config["MODEL_NAME"],
)

retriever = MilvusEmbeddingRetriever(
    document_store=document_store,
    top_k=20
)

reranker = SentenceTransformersSimilarityRanker(
    model=RERANK_MODEL,
    top_k=10
)

chat_generator = OpenAIChatGenerator(
    api_key=Secret.from_token(llm_config["VLLM_API_KEY"]),
    api_base_url=f"{llm_config['VLLM_LLM_URL']}/v1",
    model=llm_config["MODEL_NAME"],
    generation_kwargs={
        "temperature": 0.0,
        "top_p": 1.0,
        "seed": 42,
    }
)

prompt_builder = ChatPromptBuilder(
    template=template,
    required_variables=["question", "documents"]
)

reranker.warm_up()

advanced_rag_pipeline = Pipeline()
advanced_rag_pipeline.add_component("text_embedder", text_embedder)
advanced_rag_pipeline.add_component("retriever", retriever)
advanced_rag_pipeline.add_component("reranker", reranker)
advanced_rag_pipeline.add_component("prompt_builder", prompt_builder)
advanced_rag_pipeline.add_component("llm", chat_generator)

advanced_rag_pipeline.connect("text_embedder.embedding", "retriever.query_embedding")
advanced_rag_pipeline.connect("retriever.documents", "reranker.documents")
advanced_rag_pipeline.connect("reranker.documents", "prompt_builder.documents")
advanced_rag_pipeline.connect("prompt_builder.prompt", "llm.messages")
# Out:
# The CrossEncoder `tokenizer_kwargs` argument was renamed and is now deprecated. Please use `processor_kwargs` instead.
# Loading weights: 100%|██████████| 105/105 [00:00<00:00, 10993.01it/s]
# <haystack.core.pipeline.pipeline.Pipeline object at 0x7f46ef9f1a90>
# 🚅 Components
#   - text_embedder: OpenAITextEmbedder
#   - retriever: MilvusEmbeddingRetriever
#   - reranker: SentenceTransformersSimilarityRanker
#   - prompt_builder: ChatPromptBuilder
#   - llm: OpenAIChatGenerator
# 🛤️ Connections
#   - text_embedder.embedding -> retriever.query_embedding (list[float])
#   - retriever.documents -> reranker.documents (List[Document])
#   - reranker.documents -> prompt_builder.documents (list[Document])
#   - prompt_builder.prompt -> llm.messages (list[ChatMessage])

# %% [markdown]
# ## Helper function for evaluation queries
#
# The function below:
# - embeds the user question
# - retrieves an initial candidate set from Milvus
# - reranks those candidates with the cross-encoder
# - prints the reranked sources and short snippets
# - runs the full pipeline
# - prints the final answer
# - returns both the reranked documents and the final answer
#
# This makes it easier to compare retrieval behavior and final responses across `rag_basic`, `rag_vectordb`, and `rag_reranker`.

# %%
def run_reranker_query(question, retriever_top_k=20, reranker_top_k=10):
    print("=" * 80)
    print("QUESTION:")
    print(question)
    print("=" * 80)

    retrieval_start = time.perf_counter()

    q_emb = text_embedder.run(text=question)["embedding"]

    retr_out = retriever.run(query_embedding=q_emb, top_k=retriever_top_k)
    candidate_docs = retr_out["documents"]

    rerank_out = reranker.run(
        query=question,
        documents=candidate_docs,
        top_k=reranker_top_k,
    )
    top_docs = rerank_out["documents"]

    retrieval_time_s = round(time.perf_counter() - retrieval_start, 4)

    print(
        f"\nRERANKED DOCUMENTS: {len(top_docs)} "
        f"(from {len(candidate_docs)} retrieved candidates)"
    )
    print(f"RETRIEVAL + RERANK TIME (s): {retrieval_time_s}\n")

    for i, d in enumerate(top_docs, 1):
        source = d.meta.get("file_name", d.meta.get("file_path", "unknown source"))
        department = d.meta.get("department", "unknown department")
        snippet = (d.content or "")[:400].replace("\n", " ")
        print(f"[{i}] Source: {source} | Department: {department}")
        print(f"    {snippet}...")
        print()

    generation_start = time.perf_counter()

    result = advanced_rag_pipeline.run({
        "text_embedder": {"text": question},
        "retriever": {"top_k": retriever_top_k},
        "reranker": {"query": question, "top_k": reranker_top_k},
        "prompt_builder": {"question": question},
    })

    answer = result["llm"]["replies"][0].text
    generation_time_s = round(time.perf_counter() - generation_start, 4)

    print("=" * 80)
    print("FINAL ANSWER:")
    print("=" * 80)
    print(answer)
    print(f"\nGENERATION TIME (s): {generation_time_s}")

    return top_docs, answer, retrieval_time_s, generation_time_s

# %%
def run_and_save_reranker(question, scenario_id, retriever_top_k=20, reranker_top_k=10):
    top_docs, answer, retrieval_time_s, generation_time_s = run_reranker_query(
        question,
        retriever_top_k=retriever_top_k,
        reranker_top_k=reranker_top_k,
    )

    save_result_row(
        implementation="reranker",
        scenario_id=scenario_id,
        question=question,
        generated_answer=answer,
        top_docs=top_docs,
        retriever_top_k=retriever_top_k,
        reranker_top_k=reranker_top_k,
        indexing_time_s=indexing_time_s,
        retrieval_time_s=retrieval_time_s,
        generation_time_s=generation_time_s,
        results_csv=RESULTS_CSV,
    )

    return top_docs, answer

# %% [markdown]
# ## Evaluation scenarios
#
# The following five questions are used as progressively more demanding evaluation scenarios:
#
# 1. Basic fact retrieval
# 2. Procedural retrieval
# 3. Multi-team operational reasoning
# 4. Policy and exception handling
# 5. Cross-functional enterprise reasoning
#
# Together, these scenarios help test not only retrieval accuracy, but also whether the model can use the retrieved context to produce grounded, source-based answers of increasing complexity.

# %% [markdown]
# ### Scenario 1 — Basic fact retrieval
#
# This is the clean baseline scenario. It checks whether the system can retrieve and answer a single operational fact accurately.
#
# - Retrieval type: single-document, single-fact lookup
# - Main test: exact fact retrieval
# - Likely supporting source: Customer Success / Support SLA material

# %%
top_docs_s1, answer_s1 = run_and_save_reranker(
    'What is the first-response SLA for a Sev-1 support incident?',
    scenario_id="r1",
    retriever_top_k=20,
    reranker_top_k=10,
)
# Out:
# ================================================================================
# QUESTION:
# What is the first-response SLA for a Sev-1 support incident?
# ================================================================================
#
# RERANKED DOCUMENTS: 10 (from 20 retrieved candidates)
# RETRIEVAL + RERANK TIME (s): 0.4658
#
# [1] Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx | Department: Q&A Hanbooks
#     Customer Success and Support Handbook Specialised Q&A **Q: Who owns customer communication during a Sev-1 incident?** **A:** The assigned support lead owns the operational updates, but the Customer Success Manager owns stakeholder alignment and executive communication. If the issue touches release risk or hardware failure, Engineering or Logistics may join the bridge. **Q: What is the target first...
#
# [2] Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx | Department: Q&A Hanbooks
#     Customer Success and Support Handbook Service targets and escalation guide Sev-1 first response, **Target** = 15 min. Sev-1 first response, **Reviewed by** = Support manager. Sev-1 first response, **Notes** = Clock starts when the case is correctly classified. Sev-2 first response, **Target** = 1 hour. Sev-2 first response, **Reviewed by** = Support manager. Sev-2 first response, **Notes** = Inclu...
#
# [3] Source: TEAMQA-ENG-001_OrchestrAI_Engineering_Platform_and_Edge_Systems_Handbook.docx | Department: Q&A Hanbooks
#     Edge package rollout, **Target response** = Same-day readiness review. Edge package rollout, **Cross-functional coordination** = Coordinate with Logistics for warehouse maintenance windows.. SEV-1 incident, **Required engineering action** = Assign incident commander, freeze unrelated deploys, and produce a mitigation path.. SEV-1 incident, **Target response** = Within 10 min. SEV-1 incident, **Cro...
#
# [4] Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx | Department: Q&A Hanbooks
#     = Support lead. Go-live support, **Outputs** = Bridge ownership, status updates, incident routing. Go-live support, **Escalate when** = Sev-1 or Sev-2 impacts production operations. Steady-state service, **Trigger** = Routine tickets, product questions, adoption coaching. Steady-state service, **Primary owner** = Support engineer / CSM. Steady-state service, **Outputs** = Case resolution, adoption...
#
# [5] Source: VAL-CS-001_Severity_Matrix.docx | Department: Customer Support
#     Severity Matrix Classification rules  Sev-1, **Typical condition** = Critical production outage at one or more active sites. Sev-1, **Examples** = Pick-path execution blocked, gateway fleet offline, order waves cannot be released. Sev-1, **Response target** = 15 minutes. Sev-1, **Escalate to** = Support manager, Engineering incident lead, CSM. Sev-2, **Typical condition** = Major degradation with ...
#
# [6] Source: TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx | Department: Q&A Hanbooks
#     Priority and SLA Reference P1, **Typical Example** = Site-wide outage, identity lockout for warehouse shift, executive meeting room failure during customer event. P1, **First Response** = 15 minutes. P1, **Resolution Target** = 4 hours or managed workaround. P2, **Typical Example** = Department-level issue, degraded VPN, multiple device enrollment failures. P2, **First Response** = 30 minutes. P2,...
#
# [7] Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx | Department: Q&A Hanbooks
#     that hardware shipment dates are realistic. **Q: How are support severities defined?** **A:** Severity is tied to operational impact. Sev-1 means a critical warehouse process cannot run in production. Sev-2 means a major function is degraded with no acceptable workaround. Sev-3 covers localized defects or time-sensitive questions. Sev-4 is low-impact guidance or enhancement clarification....
#
# [8] Source: VAL-CS-004_Renewal_Risk_Signals_Brief.docx | Department: Customer Support
#     Renewal Risk Signals Brief Primary risk signals  Repeated Sev-1/Sev-2 incidents, **Why it matters** = Operational trust erodes quickly when warehouse work is repeatedly disrupted.. Repeated Sev-1/Sev-2 incidents, **Review threshold** = 2 or more major incidents in 90 days. Repeated Sev-1/Sev-2 incidents, **Typical action** = Open recovery plan and executive review. Declining adoption of core workf...
#
# [9] Source: VAL-ENG-001_Release_Freeze_Notice.docx | Department: Engineering
#     Release Freeze Notice Approval path for freeze exceptions Sev-1 production outage, **Status** = Permitted with emergency approval. Sev-1 production outage, **Approver** = Incident Commander + Director of Platform Delivery. Sev-1 production outage, **Required evidence** = Rollback plan and post-incident review required. Critical security remediation, **Status** = Permitted with security approval. C...
#
# [10] Source: VAL-CS-001_Severity_Matrix.docx | Department: Customer Support
#     sync failure, dashboard data delayed during active operations. Sev-2, **Response target** = 1 hour. Sev-2, **Escalate to** = Support manager and product duty lead. Sev-3, **Typical condition** = Localized issue or time-sensitive operational question. Sev-3, **Examples** = Role-based permission mismatch, report export issue, integration retry error. Sev-3, **Response target** = 4 business hours. Se...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# The first-response SLA for a Sev-1 support incident is 15 minutes.
#
# (TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx, TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx, VAL-CS-001_Severity_Matrix.docx)
#
# GENERATION TIME (s): 1.5835
# Saved result in /nvme/h/cy26nk2/Thesis/data/results/experimental/hpc_results.csv

# %% [markdown]
# ### Scenario 2 — Procedural retrieval
#
# This scenario is slightly more complex because the answer is not a single fact but a short operational process.
#
# - Retrieval type: checklist or procedure retrieval
# - Main test: whether the system can recover and summarize a structured process
# - Likely supporting source: onboarding or enablement documentation

# %%
top_docs_s2, answer_s2 = run_and_save_reranker(
    'What steps must be completed before a new employee is considered ready for day one at OrchestrAI?',
    scenario_id="r2",
    retriever_top_k=20,
    reranker_top_k=10,
)
# Out:
# ================================================================================
# QUESTION:
# What steps must be completed before a new employee is considered ready for day one at OrchestrAI?
# ================================================================================
#
# RERANKED DOCUMENTS: 10 (from 20 retrieved candidates)
# RETRIEVAL + RERANK TIME (s): 0.4449
#
# [1] Source: VAL-HR-001_Day_One_Onboarding_Checklist.docx | Department: HR
#     Day-One Onboarding Checklist **Document ID:** VAL-HR-001 **Owner:** HR & People Operations **Confidentiality:** Internal Use Only Purpose: This checklist standardizes the minimum tasks that must be complete before an OrchestrAI employee can be considered ready for day-one onboarding. **Department**, **Value** = HR & People Operations. **Effective date**, **Value** = 2026-02-24. **Applies to**, **V...
#
# [2] Source: TEAMQA-HR-001_OrchestrAI_HR_and_People_Operations_Handbook.docx | Department: Q&A Hanbooks
#     HR and People Operations Handbook Specialised Q&A **Q: What does HR and People Operations own at OrchestrAI?** **A:** The team owns employee record quality, onboarding coordination, policy communication, leave administration, manager guidance, workplace process alignment, and lifecycle-event execution. Sensitive employment matters may involve leadership or legal review, but People Ops remains the ...
#
# [3] Source: VAL-PROD-001_Launch_Readiness_Checklist.docx | Department: Product
#     **OrchestrAI Team Knowledge Base** **Launch Readiness Checklist** Operational checklist used by Product and PMO to confirm whether a customer-facing release may proceed to go-live. **Effective Date**  2026-03-24, **Department**  Product & Program Management = **Review Cycle**  Quarterly. **Effective Date**  2026-03-24, **Owner**  Program Management Office = **Audience**  PMO, Product, Engineering,...
#
# [4] Source: VAL-FIN-003_Vendor_Onboarding_Requirements.docx | Department: Finance
#     Vendor Onboarding Requirements **Document ID:** VAL-FIN-003 **Owner:** Procurement Operations **Confidentiality:** Internal Use Only Purpose: This document lists the minimum requirements that must be satisfied before a new supplier can be activated for purchasing or payment in OrchestrAI systems. **Effective date**, **Value** = 2026-03-06. **Applies to**, **Value** = New suppliers and reactivated ...
#
# [5] Source: VAL-SEC-005_Third_Party_Access_Approval_Standard.docx | Department: Security
#     granting third parties access to OrchestrAI resources. It applies to cloud environments, ticketing tools, identity platforms, source repositories, diagnostics portals, and any controlled workspace or warehouse system where external personnel may need temporary access. **Approval Principles** Every third-party account must have a named OrchestrAI business sponsor who confirms business need, duratio...
#
# [6] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     the onboarding workflow, which syncs into AtlasDesk after the employee record is created. IT does not build a device against informal chat messages or spreadsheet lists. **Q: What information is required before IT can stage a device?** A: IT needs the employee name, manager, office or shipping location, employment type, start date, preferred platform when policy allows, cost center, and any approv...
#
# [7] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     = **Related Docs**. **Primary Systems**, IT Workplace Services = TEAMQA-IT-001; VAL-IT-002 **Purpose.** This FAQ explains how OrchestrAI provisions standard corporate laptops for new hires, internal transfers, refresh cycles, and replacement requests. It is written for employees, hiring managers, and local site coordinators who need quick answers about request timing, approvals, imaging, asset tag...
#
# [8] Source: VAL-SEC-003_Patch_Compliance_Reminder.docx | Department: Security
#     **OrchestrAI Security Advisory** **Patch Compliance Reminder** Infrastructure, endpoint, and edge appliance patching requirements for standard and mission-critical assets **Effective Date**  2026-03-24, **Department**  Security = **Review Cycle**  Monthly. **Effective Date**  2026-03-24, **Owner**  Security Operations = **Audience**  IT, Engineering, Field Ops. **Effective Date**  2026-03-24, **Ve...
#
# [9] Source: TEAMQA-ENG-001_OrchestrAI_Engineering_Platform_and_Edge_Systems_Handbook.docx | Department: Q&A Hanbooks
#     rules. All production-impacting changes require a linked work item, code review, test evidence, and rollback notes. Schema changes must include a compatibility statement and a migration sequencing plan. Feature flags are preferred when operational risk is non-trivial or customer workflow impact is hard to predict. Any change affecting Edge Gateway or Device Agent behavior must define supported fir...
#
# [10] Source: VAL-IT-002_MFA_Enrollment_Guide.docx | Department: IT
#     key, Primary Use = Privileged access and travel use. Hardware security key, Allowed For Admin Roles = Yes. Hardware security key, Notes = Required for designated admin groups.. SMS fallback, Primary Use = Temporary recovery only. SMS fallback, Allowed For Admin Roles = No. SMS fallback, Notes = Permitted only after service desk validation. **3. Enrollment Procedure** Sign in to the OrchestrAI iden...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# According to the Day-One Onboarding Checklist (VAL-HR-001_Day_One_Onboarding_Checklist.docx), the minimum tasks that must be completed before a new employee can be considered ready for day-one onboarding are not explicitly listed in the provided context. However, the HR and People Operations Handbook (TEAMQA-HR-001_OrchestrAI_HR_and_People_Operations_Handbook.docx) states that a new hire is considered onboarding-complete after required documents are recorded, payroll setup is confirmed, IT has completed core access and device delivery, and orientation is completed.
#
# Therefore, the steps that must be completed before a new employee is considered ready for day one at OrchestrAI include:
#
# 1. Required documents are recorded.
# 2. Payroll setup is confirmed.
# 3. IT has completed core access.
# 4. IT has delivered a device.
# 5. Orientation is completed.
#
# The retrieved context is insufficient to provide a comprehensive list of steps, but the above-mentioned steps are the minimum requirements mentioned in the provided context.
#
# GENERATION TIME (s): 3.5913
# Saved result in /nvme/h/cy26nk2/Thesis/data/results/experimental/hpc_results.csv

# %% [markdown]
# ### Scenario 3 — Multi-team operational reasoning
#
# This scenario requires combining information from more than one team to answer a realistic workplace problem.
#
# - Retrieval type: multi-document, cross-team retrieval
# - Main test: whether the system can synthesize HR, IT, and access-related responsibilities
# - Likely supporting sources: onboarding, IT, and security guidance

# %%
top_docs_s3, answer_s3 = run_and_save_reranker(
    'A new engineer starts on Monday, but their laptop has not arrived and their required access is still pending. Which teams are involved and what should happen next?',
    scenario_id="r3",
    retriever_top_k=20,
    reranker_top_k=10,
)
# Out:
# ================================================================================
# QUESTION:
# A new engineer starts on Monday, but their laptop has not arrived and their required access is still pending. Which teams are involved and what should happen next?
# ================================================================================
#
# RERANKED DOCUMENTS: 10 (from 20 retrieved candidates)
# RETRIEVAL + RERANK TIME (s): 0.4138
#
# [1] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     Common Questions **Q: How far in advance should a laptop be requested?** A: Standard new-hire laptop requests should be present in the hiring workflow at least seven business days before the employee start date. International shipments, executive hires, and custom software bundles may require ten to fifteen business days. **Q: Which team starts the request?** A: The request begins with the hiring ...
#
# [2] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     1 business day. Non-standard software or admin rights request, **Primary Owner** = Endpoint Engineering. Non-standard software or admin rights request, **Escalation Trigger** = Security review required before release. Shipment delay or damaged delivery, **Primary Owner** = Regional IT / Logistics. Shipment delay or damaged delivery, **Escalation Trigger** = Escalate when delivery risk affects star...
#
# [3] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     AtlasDesk within one business day. **Q: What happens if a laptop is not available in local stock?** A: IT allocates the closest approved catalog model when possible. If no standard device is available, the request is escalated to Procurement and the hiring manager is notified of revised delivery timing and fallback options. **Q: Who records the asset tag and serial number?** A: The asset coordinat...
#
# [4] Source: VAL-SEC-003_Patch_Compliance_Reminder.docx | Department: Security
#     Cloud production services, **Target window** = 72 hrs critical / 7 days high. Cloud production services, **Non-compliance trigger** = Any overdue critical patch. Cloud production services, **Required escalation** = Notify Security, service owner, and on-call engineering lead. Employee laptops and corp desktops, **Target window** = Next scheduled cycle; max 14 days for urgent items. Employee laptop...
#
# [5] Source: VAL-SEC-003_Patch_Compliance_Reminder.docx | Department: Security
#     maintenance cadence, but laptops or workstations missing two consecutive cycles are considered non-compliant and subject to restricted access. **Patching cadence by asset class**...
#
# [6] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     = **Related Docs**. **Primary Systems**, IT Workplace Services = TEAMQA-IT-001; VAL-IT-002 **Purpose.** This FAQ explains how OrchestrAI provisions standard corporate laptops for new hires, internal transfers, refresh cycles, and replacement requests. It is written for employees, hiring managers, and local site coordinators who need quick answers about request timing, approvals, imaging, asset tag...
#
# [7] Source: TEAMQA-HR-001_OrchestrAI_HR_and_People_Operations_Handbook.docx | Department: Q&A Hanbooks
#     title, employment type, start date, and any special equipment or access requirements that need partner coordination. **Q: How does People Operations work with IT during onboarding?** **A:** People Ops provides start-date and role data, while IT provisions the device, identity account, and baseline tools. If the role requires elevated access, Security reviews the request through AccessHub rather th...
#
# [8] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     **Scope note:** This document covers standard Windows and macOS employee laptops. Warehouse handhelds, kiosk terminals, and engineering lab devices follow separate fulfillment rules. **Provisioning Timeline Snapshot** Request intake, **Owner** = Hiring manager / HRIS. Request intake, **Typical Target** = Day -10 to -7. Request intake, **Key Output** = Valid hire record and cost center. Device sele...
#
# [9] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     Decision and Escalation Reference Start date within 72 hours and no assigned device, **Primary Owner** = IT Service Desk Lead. Start date within 72 hours and no assigned device, **Escalation Trigger** = Notify hiring manager and regional IT manager. Requested model unavailable in stock, **Primary Owner** = Asset Coordinator. Requested model unavailable in stock, **Escalation Trigger** = Escalate t...
#
# [10] Source: TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx | Department: Q&A Hanbooks
#     Team Q&A **Q: Who approves software installations?** **A:** Standard catalog apps can be self-requested or manager-approved depending on license cost. Non-standard software requires manager approval and an IT compatibility check; Security review is required for higher-risk tools. **Q: How does IT handle onboarding?** **A:** IT receives an approved hire record, prepares account and hardware based o...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# Based on the provided context, the teams involved are IT, People Operations, and Security.
#
# The hiring manager, who is also the primary owner for request intake, should have submitted the request at least seven business days before the employee start date. However, since the laptop has not arrived and the required access is still pending, the situation has escalated.
#
# According to the Decision and Escalation Reference in VAL-IT-001_Laptop_Provisioning_FAQ.docx, if the start date is within 72 hours and no assigned device is available, the primary owner is the IT Service Desk Lead. The escalation trigger is to notify the hiring manager and regional IT manager.
#
# Therefore, the IT Service Desk Lead should be notified, and they should escalate the issue to the hiring manager and regional IT manager.
#
# GENERATION TIME (s): 2.7977
# Saved result in /nvme/h/cy26nk2/Thesis/data/results/experimental/hpc_results.csv

# %% [markdown]
# ### Scenario 4 — Policy and exception handling
#
# This scenario checks whether the system can distinguish the normal rule from the emergency exception path.
#
# - Retrieval type: policy retrieval with exception logic
# - Main test: whether the system can identify when a standard workflow may be bypassed
# - Likely supporting source: procurement, operations, or incident-response policy

# %%
top_docs_s4, answer_s4 = run_and_save_reranker(
    'Can OrchestrAI make an urgent hardware purchase without following the normal PO workflow if a warehouse outage is at risk?',
    scenario_id="r4",
    retriever_top_k=20,
    reranker_top_k=10,
)
# Out:
# ================================================================================
# QUESTION:
# Can OrchestrAI make an urgent hardware purchase without following the normal PO workflow if a warehouse outage is at risk?
# ================================================================================
#
# RERANKED DOCUMENTS: 10 (from 20 retrieved candidates)
# RETRIEVAL + RERANK TIME (s): 0.4305
#
# [1] Source: TEAMQA-SALES-001_OrchestrAI_Sales_and_Solutions_Handbook.docx | Department: Q&A Hanbooks
#     opportunity has a documented warehouse problem, a credible business sponsor, a timeline that matches operational constraints, a measurable business case, and enough process detail to determine whether OrchestrAI can support the workflow without hidden delivery risk. **Q: When must a Solutions Consultant join a deal?** **A:** A Solutions Consultant must join when the opportunity involves integratio...
#
# [2] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook 5. Operational Questions and Answers How should urgent replacement units be prioritized? Urgent replacements are prioritized using business impact rather than requester seniority. P1 means a live customer site is degraded or offline; P2 means the site is at operational risk within 24 hours; P3 covers planned swap-outs and non-critical reserves. T...
#
# [3] Source: VAL-IT-005_Password_Reset_Escalation_SOP.docx | Department: IT
#     Purpose and scope This standard operating procedure defines how OrchestrAI IT handles password reset requests that cannot be completed through the normal self-service flow. It applies to workforce identity accounts, selected support-managed shared identities, and urgent access restoration cases involving business-critical users. Do not treat a password reset as routine when the request involves an...
#
# [4] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook 5. Operational Questions and Answers What service levels apply to routine outbound requests? Routine in-region outbound requests submitted before 12:00 local warehouse time are targeted for next-business-day dispatch, assuming stock is available and compliance checks are complete. Requests received after the cutoff roll to the next planning windo...
#
# [5] Source: TEAMQA-FIN-001_OrchestrAI_Finance_and_Procurement_Handbook.docx | Department: Q&A Hanbooks
#     Finance and Procurement Handbook Specialised Q&A **A:** Security review is required when the vendor will access OrchestrAI systems, process internal data, host critical workflows, or support services that create operational or privacy risk. **Q: How are hardware purchases handled differently from software subscriptions?** **A:** Hardware purchases often require receiving confirmation, serial track...
#
# [6] Source: TEAMQA-ENG-001_OrchestrAI_Engineering_Platform_and_Edge_Systems_Handbook.docx | Department: Q&A Hanbooks
#     rules. All production-impacting changes require a linked work item, code review, test evidence, and rollback notes. Schema changes must include a compatibility statement and a migration sequencing plan. Feature flags are preferred when operational risk is non-trivial or customer workflow impact is hard to predict. Any change affecting Edge Gateway or Device Agent behavior must define supported fir...
#
# [7] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook 2. Team Mission and Operating Context The Logistics and Field Fulfillment team ensures that OrchestrAI hardware and deployment kits move from inbound receiving to customer-ready shipment without losing traceability, asset integrity, or installation timing. The team sits at the boundary between software planning and physical execution: it converts...
#
# [8] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook Document ID: TEAMQA-LOG-001  |  Department: Logistics and Field Fulfillment  |  Version: 1.0 Scope: warehouse receiving, outbound orchestration, spare device movement, installation logistics, and exception handling **Purpose.** This handbook answers the most common operational questions raised by logistics coordinators, field deployment planners,...
#
# [9] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook 5. Operational Questions and Answers Can engineering request direct shipment from incoming stock before quality checks are complete? No. Incoming stock is not eligible for direct customer dispatch until receiving, count verification, and baseline quality checks are complete. Fast-tracking is possible only after the operations manager explicitly a...
#
# [10] Source: TEAMQA-FIN-001_OrchestrAI_Finance_and_Procurement_Handbook.docx | Department: Q&A Hanbooks
#     Finance and Procurement Handbook Function scope and operating principles Finance and Procurement at OrchestrAI owns spend controls, purchase-order governance, vendor setup, reimbursement policy administration, month-end readiness, and reporting support for cross-functional teams. The function works closely with Sales on pricing and margin exceptions, with Logistics on hardware purchasing and retur...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# According to the TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx, urgent replacements are prioritized using business impact rather than requester seniority. However, it does not explicitly state that an urgent hardware purchase can be made without following the normal PO workflow in the case of a warehouse outage.
#
# However, according to the TEAMQA-FIN-001_OrchestrAI_Finance_and_Procurement_Handbook.docx, Finance and Procurement at OrchestrAI owns spend controls, purchase-order governance, vendor setup, reimbursement policy administration, month-end readiness, and reporting support for cross-functional teams.
#
# The TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx also states that urgent replacements are prioritized using business impact rather than requester seniority, and that the logistics team may reorder same-day fulfillment queues only when the priority has been validated by support or customer success.
#
# Therefore, it can be inferred that in the case of a warehouse outage, an urgent hardware purchase may be made without following the normal PO workflow, but this would require validation by support or customer success and prioritization based on business impact.
#
# Document ID: TEAMQA-LOG-001  |  Department: Logistics and Field Fulfillment  |  Version: 1.0
#
# GENERATION TIME (s): 4.4561
# Saved result in /nvme/h/cy26nk2/Thesis/data/results/experimental/hpc_results.csv

# %% [markdown]
# ### Scenario 5 — Cross-functional enterprise reasoning
#
# This is the most demanding scenario in the notebook because it requires cross-functional reasoning across several business areas.
#
# - Retrieval type: multi-hop, multi-document retrieval
# - Main test: whether the system can combine support, product, logistics, and commercial risk signals into one grounded answer
# - Likely supporting sources: customer success, product, support, and logistics material

# %%
top_docs_s5, answer_s5 = run_and_save_reranker(
    'A customer renewal is at risk because support cases are recurring, a requested feature is still unavailable, and replacement hardware is delayed. What should OrchestrAI do next, and which teams must be involved?',
    scenario_id="r5",
    retriever_top_k=20,
    reranker_top_k=10,
)
# Out:
# ================================================================================
# QUESTION:
# A customer renewal is at risk because support cases are recurring, a requested feature is still unavailable, and replacement hardware is delayed. What should OrchestrAI do next, and which teams must be involved?
# ================================================================================
#
# RERANKED DOCUMENTS: 10 (from 20 retrieved candidates)
# RETRIEVAL + RERANK TIME (s): 0.4398
#
# [1] Source: VAL-CS-004_Renewal_Risk_Signals_Brief.docx | Department: Customer Support
#     Renewal Risk Signals Brief **Document ID:** VAL-CS-004 **Department:** Customer Success & Support **Confidentiality:** Internal Use Only **Effective date**, Director, Customer Success Operations = 2026-02-10. **Effective date**, **Document type** = **Review date**. **Effective date**, Risk brief = 2026-08-10 Purpose: Defines the most important signals used by OrchestrAI Customer Success teams to i...
#
# [2] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook 5. Operational Questions and Answers How should urgent replacement units be prioritized? Urgent replacements are prioritized using business impact rather than requester seniority. P1 means a live customer site is degraded or offline; P2 means the site is at operational risk within 24 hours; P3 covers planned swap-outs and non-critical reserves. T...
#
# [3] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook 5. Operational Questions and Answers What is the escalation path for repeated carrier failures in one region? Escalate first to the regional carrier coordinator, then to the logistics operations manager, and then to procurement if a contract remedy or alternate carrier decision is required. If customer dates are already at risk, customer success ...
#
# [4] Source: TEAMQA-FIN-001_OrchestrAI_Finance_and_Procurement_Handbook.docx | Department: Q&A Hanbooks
#     Finance and Procurement Handbook Specialised Q&A **A:** Security review is required when the vendor will access OrchestrAI systems, process internal data, host critical workflows, or support services that create operational or privacy risk. **Q: How are hardware purchases handled differently from software subscriptions?** **A:** Hardware purchases often require receiving confirmation, serial track...
#
# [5] Source: TEAMQA-ENG-001_OrchestrAI_Engineering_Platform_and_Edge_Systems_Handbook.docx | Department: Q&A Hanbooks
#     rules. All production-impacting changes require a linked work item, code review, test evidence, and rollback notes. Schema changes must include a compatibility statement and a migration sequencing plan. Feature flags are preferred when operational risk is non-trivial or customer workflow impact is hard to predict. Any change affecting Edge Gateway or Device Agent behavior must define supported fir...
#
# [6] Source: TEAMQA-SALES-001_OrchestrAI_Sales_and_Solutions_Handbook.docx | Department: Q&A Hanbooks
#     opportunity has a documented warehouse problem, a credible business sponsor, a timeline that matches operational constraints, a measurable business case, and enough process detail to determine whether OrchestrAI can support the workflow without hidden delivery risk. **Q: When must a Solutions Consultant join a deal?** **A:** A Solutions Consultant must join when the opportunity involves integratio...
#
# [7] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     into actual movement of equipment and materials. At OrchestrAI, the logistics function does not only ship standard hardware. It also supports replacement gateway appliances, calibrated barcode scanners, installation spares, return merchandise authorizations, secure wipe returns, and country-specific documentation needed for cross-border fulfillment. Because of that breadth, the team must maintain ...
#
# [8] Source: VAL-PROD-001_Launch_Readiness_Checklist.docx | Department: Product
#     **OrchestrAI Team Knowledge Base** **Launch Readiness Checklist** Operational checklist used by Product and PMO to confirm whether a customer-facing release may proceed to go-live. **Effective Date**  2026-03-24, **Department**  Product & Program Management = **Review Cycle**  Quarterly. **Effective Date**  2026-03-24, **Owner**  Program Management Office = **Audience**  PMO, Product, Engineering,...
#
# [9] Source: TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx | Department: Q&A Hanbooks
#     Team Q&A **Q: What does the IT team own at OrchestrAI?** **A:** IT owns end-user computing, collaboration services, ticket triage, endpoint compliance, warehouse device support, and coordination with Security, Engineering, and vendors for shared systems. **Q: How should users request help?** **A:** All support requests should be logged in AtlasDesk unless there is a declared outage or the user can...
#
# [10] Source: VAL-IT-005_Password_Reset_Escalation_SOP.docx | Department: IT
#     Purpose and scope This standard operating procedure defines how OrchestrAI IT handles password reset requests that cannot be completed through the normal self-service flow. It applies to workforce identity accounts, selected support-managed shared identities, and urgent access restoration cases involving business-critical users. Do not treat a password reset as routine when the request involves an...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# Based on the provided context, the next steps for OrchestrAI to take when a customer renewal is at risk are not explicitly stated. However, we can infer that the following teams must be involved:
#
# 1. Customer Success: As mentioned in the Renewal Risk Signals Brief (VAL-CS-004), the Customer Success team is responsible for identifying accounts that may be at risk before a renewal or expansion cycle.
# 2. Support: The Support team is mentioned in the Renewal Risk Signals Brief as one of the teams that can validate the priority of urgent replacement units (TEAMQA-LOG-001).
# 3. Logistics: The Logistics team is responsible for shipping and replacing hardware, and they must maintain tight coordination with engineering release managers, security reviewers, customer success managers, and regional implementation leads (TEAMQA-LOG-001).
# 4. Engineering: The Engineering team is responsible for ensuring that production-impacting changes are properly reviewed and tested (TEAMQA-ENG-001).
# 5. Procurement: The Procurement team is responsible for handling hardware purchases and ensuring that they are properly tracked and coordinated (TEAMQA-FIN-001).
#
# As for the next steps, the provided context does not explicitly state what OrchestrAI should do next. However, it is likely that the Customer Success team would work with the Support team to validate the priority of the customer's issues and determine the best course of action to resolve them. The Logistics team would likely be involved in shipping and replacing the delayed hardware, and the Engineering team would ensure that any necessary changes are properly reviewed and tested. The Procurement team would likely be involved in ensuring that the hardware purchases are properly tracked and coordinated.
#
# The retrieved context is insufficient to provide a specific answer to the question of what OrchestrAI should do next.
#
# GENERATION TIME (s): 5.6632
# Saved result in /nvme/h/cy26nk2/Thesis/data/results/experimental/hpc_results.csv
