# %% [markdown]
# # Vector RAG Pipeline on the OrchestrAI Synthetic Enterprise Corpus
#
# This notebook demonstrates an advanced Retrieval-Augmented Generation (RAG) pipeline built on the same OrchestrAI synthetic enterprise corpus as the basic notebook.
#
# Compared with the basic notebook, this version adds:
# - richer document processing through **Docling**
# - tokenizer-aware chunking with **HybridChunker**
# - an additional safety split before embedding
# - a real **Milvus** vector database backend
# - explicit source metadata normalization for cleaner retrieval and citations
#
# **Outputs and IDs:** Logged as `implementation="vectordb"` with scenario IDs `v1`–`v5` to `data/results/experimental/hpc_results.csv`. Dense retriever **`top_k=10`**. Each run clears only previous `vectordb` rows before saving. See `README.md` for evaluation and repository layout.

# %% [markdown]
# ## What is different from the basic notebook?
#
# ### Basic pipeline
# - direct DOCX conversion
# - simple splitting
# - in-memory document store
# - simpler indexing flow
#
# ### Advanced pipeline
# - richer conversion and chunking
# - persistent vector storage in Milvus
# - more robust source metadata handling
# - a more realistic enterprise-style retrieval pipeline

# %% [markdown]
# ## Environment requirements
#
# This notebook assumes:
# - Python **3.12** (recommended) and dependencies from `requirements.txt`
# - vLLM services are running and reachable from this HPC job/session
# - `/nvme/scratch/cy26nk2/llm.env` and `/nvme/scratch/cy26nk2/embd.env` exist with valid API keys, URLs, and model names
# - a **Milvus server** is running at `http://localhost:19530` (start with `bash scripts/standalone_embed.sh start`)
# - the OrchestrAI corpus under **`data/dummy_data/`** (see code: `PROJECT_ROOT / "data" / "dummy_data"`)
# - the first code cell prepends **`src/`** to `sys.path` for `results_logger`
#
# Run the optional install cell once if packages are missing.

# %% [markdown]
# ## Imports and runtime checks

# %%
import sys , os
import warnings
import time
from pathlib import Path


PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks-hpc" else Path.cwd()
SRC_DIR = PROJECT_ROOT / "src"

if str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

warnings.filterwarnings("ignore")

print("Python:", sys.executable)

from dotenv import dotenv_values
llm_config = dotenv_values('/nvme/scratch/cy26nk2/llm.env')
embd_config = dotenv_values('/nvme/scratch/cy26nk2/embd.env')
print("LLM model loaded:", llm_config.get("MODEL_NAME", "<missing>"))
print("Embedder model loaded:", embd_config.get("MODEL_NAME", "<missing>"))

import importlib
import results_logger
importlib.reload(results_logger)
from results_logger import save_result_row, clear_results_for_implementation
RESULTS_CSV = PROJECT_ROOT / "data" / "results" / "experimental" / "hpc_results.csv"
clear_results_for_implementation("vectordb", results_csv=RESULTS_CSV)

from haystack import Pipeline
from haystack.dataclasses import ChatMessage
from haystack.components.builders import ChatPromptBuilder
from haystack.components.writers import DocumentWriter
from haystack.components.preprocessors import DocumentSplitter, DocumentCleaner

from milvus_haystack import MilvusDocumentStore
from milvus_haystack.milvus_embedding_retriever import MilvusEmbeddingRetriever

from haystack.components.embedders import OpenAIDocumentEmbedder, OpenAITextEmbedder
from haystack.components.generators.chat import OpenAIChatGenerator
from haystack.utils import Secret

from haystack_integrations.components.converters.docling import DoclingConverter
from docling.chunking import HybridChunker

print("Imports work")
# Out:
# Python: /nvme/h/cy26nk2/.conda/envs/notebookEnv/bin/python3.14
# LLM model loaded: meta-llama/Llama-3.1-8B-Instruct
# Embedder model loaded: BAAI/bge-m3
# Cleared existing rows for implementation='vectordb'
# Imports work

# %% [markdown]
# ## Connect to Milvus
#
# This notebook uses a Milvus server connection rather than Milvus Lite.
# This keeps the advanced notebook aligned with a real vector database deployment.

# %%
HOME_DIR = os.path.expanduser("~")
db_path = os.path.join(HOME_DIR, "Thesis/notebooks-hpc", "rag_vectordb.db")

# %%
document_store = MilvusDocumentStore(
    connection_args={"uri": db_path},
    drop_old=True,
    enable_dynamic_field=False,
)

print("Milvus ready")
# Out:
# Milvus ready

# %% [markdown]
# ## Load the OrchestrAI dataset
#
# The corpus is organized by department under **`data/dummy_data/`**; all `.docx` files are loaded recursively.

# %%
DOCUMENTS_DIR = PROJECT_ROOT / "data" / "dummy_data"
FILES = [str(f.resolve()) for f in DOCUMENTS_DIR.rglob("*.docx")]

print("Files found:", len(FILES))
for f in FILES[:10]:
    print("-", Path(f).name)
# Out:
# Files found: 54
# - VAL-SALES-002_Webinar_Launch_Brief_refreshed.docx
# - VAL-SALES-005_Discount_Exception_Policy_refreshed.docx
# - VAL-SALES-001_Lead_Routing_Rules_refreshed.docx
# - VAL-SALES-004_CRM_Field_Governance_Note_refreshed.docx
# - VAL-SALES-003_Campaign_Approval_Workflow_refreshed.docx
# - VAL-LOG-005_Reverse_Logistics_Routing_Memo.docx
# - VAL-LOG-004_Regional_Delivery_SLA_Matrix.docx
# - VAL-LOG-001_Carrier_Delay_Escalation_Notice.docx
# - VAL-LOG-002_Warehouse_Receiving_Checklist.docx
# - VAL-LOG-003_Damaged_Goods_Handling_SOP.docx

# %% [markdown]
# ## Advanced indexing strategy
#
# To make the advanced pipeline reliable, the indexing flow is:
#
# 1. Convert each file with `DoclingConverter`
# 2. Attach explicit source metadata (`file_name`, `file_path`, `department`)
# 3. Apply an additional `DocumentSplitter` before embedding
# 4. Remove metadata fields that Milvus cannot store cleanly
# 5. Generate embeddings with vLLM-served embedder
# 6. Write the embedded chunks to Milvus
#
# This file-by-file indexing approach fixes the earlier `unknown source` problem during retrieval.

# %%
OLLAMA_EMBED_MODEL = "mxbai-embed-large"
HF_TOKENIZER_ID = "mixedbread-ai/mxbai-embed-large-v1"

converter = DoclingConverter(
    chunker=HybridChunker(
        tokenizer=HF_TOKENIZER_ID,
        max_tokens=300,
    )
)

doc_embedder = OpenAIDocumentEmbedder(
    api_key=Secret.from_token(embd_config["VLLM_API_KEY"]),
    api_base_url=f"{embd_config['VLLM_EMBD_URL']}/v1",
    model=embd_config["MODEL_NAME"],
)

writer = DocumentWriter(document_store=document_store)

def normalize_meta(meta):
    cleaned = {}
    for key, value in (meta or {}).items():
        if key == "_split_overlap":
            continue
        if isinstance(value, (str, int, float, bool)) or value is None:
            cleaned[key] = value
        else:
            cleaned[key] = str(value)
    return cleaned

indexing_start = time.perf_counter()

for file_path in FILES:
    file_path = Path(file_path)

    result = converter.run(sources=[file_path])
    converted_docs = result["documents"]

    for doc in converted_docs:
        if doc.meta is None:
            doc.meta = {}
        doc.meta["file_name"] = file_path.name
        doc.meta["file_path"] = str(file_path.resolve())
        doc.meta["department"] = file_path.parent.name

    cleaner = DocumentCleaner()
    cleaned_docs = cleaner.run(documents=converted_docs)["documents"]

    for doc in cleaned_docs:
        if doc.meta is None:
            doc.meta = {}
        doc.meta["file_name"] = file_path.name
        doc.meta["file_path"] = str(file_path.resolve())
        doc.meta["department"] = file_path.parent.name

    splitter = DocumentSplitter(
        split_by="word",
        split_length=80,
        split_overlap=20
    )

    split_docs = splitter.run(documents=cleaned_docs)["documents"]

    for doc in split_docs:
        if doc.meta is None:
            doc.meta = {}
        doc.meta["file_name"] = file_path.name
        doc.meta["file_path"] = str(file_path.resolve())
        doc.meta["department"] = file_path.parent.name
        doc.meta = normalize_meta(doc.meta)

    docs_with_embeddings = doc_embedder.run(split_docs)
    writer.run(documents=docs_with_embeddings["documents"])

indexing_time_s = round(time.perf_counter() - indexing_start, 4)

print("Indexing time (s):", indexing_time_s)
print(f"Indexed {len(FILES)} source files into Milvus.")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Calculating embeddings: 1it [00:00,  2.17it/s]
# Calculating embeddings: 1it [00:00, 28.87it/s]
# Calculating embeddings: 1it [00:00, 26.82it/s]
# Calculating embeddings: 1it [00:00, 29.62it/s]
# Calculating embeddings: 1it [00:00, 30.10it/s]
# Calculating embeddings: 1it [00:00, 19.57it/s]
# Calculating embeddings: 1it [00:00, 18.53it/s]
# Calculating embeddings: 1it [00:00, 20.07it/s]
# [transformers] Token indices sequence length is longer than the specified maximum sequence length for this model (897 > 512). Running this sequence through the model will result in indexing errors
# Calculating embeddings: 1it [00:00, 12.43it/s]
# Calculating embeddings: 1it [00:00, 17.29it/s]
# Calculating embeddings: 1it [00:00, 42.78it/s]
# Calculating embeddings: 1it [00:00, 29.69it/s]
# Calculating embeddings: 1it [00:00, 41.28it/s]
# Calculating embeddings: 1it [00:00, 29.55it/s]
# Calculating embeddings: 1it [00:00, 24.95it/s]
# Calculating embeddings: 1it [00:00, 18.98it/s]
# Calculating embeddings: 1it [00:00, 24.86it/s]
# Calculating embeddings: 1it [00:00, 27.05it/s]
# Calculating embeddings: 1it [00:00, 25.03it/s]
# Calculating embeddings: 1it [00:00, 29.23it/s]
# Calculating embeddings: 1it [00:00, 15.06it/s]
# Calculating embeddings: 1it [00:00, 22.71it/s]
# Calculating embeddings: 1it [00:00, 20.88it/s]
# Calculating embeddings: 1it [00:00, 15.09it/s]
# Calculating embeddings: 1it [00:00, 17.26it/s]
# Calculating embeddings: 1it [00:00, 21.73it/s]
# Calculating embeddings: 1it [00:00, 26.88it/s]
# Calculating embeddings: 1it [00:00, 23.31it/s]
# Calculating embeddings: 1it [00:00, 26.87it/s]
# Calculating embeddings: 1it [00:00, 23.05it/s]
# Calculating embeddings: 1it [00:00, 19.05it/s]
# Calculating embeddings: 1it [00:00, 17.35it/s]
# Calculating embeddings: 1it [00:00, 17.36it/s]
# Calculating embeddings: 1it [00:00, 15.01it/s]
# Calculating embeddings: 1it [00:00, 16.65it/s]
# Calculating embeddings: 1it [00:00, 16.55it/s]
# Calculating embeddings: 1it [00:00, 15.70it/s]
# Calculating embeddings: 1it [00:00, 21.17it/s]
# Calculating embeddings: 1it [00:00, 20.38it/s]
# Calculating embeddings: 1it [00:00, 23.31it/s]
# Calculating embeddings: 1it [00:00,  8.60it/s]
# Calculating embeddings: 1it [00:00,  8.83it/s]
# Calculating embeddings: 1it [00:00,  8.34it/s]
# Calculating embeddings: 2it [00:00, 13.29it/s]
# Calculating embeddings: 1it [00:00,  8.13it/s]
# Calculating embeddings: 1it [00:00,  8.72it/s]
# Calculating embeddings: 1it [00:00,  9.45it/s]
# Calculating embeddings: 1it [00:00,  9.17it/s]
# Calculating embeddings: 1it [00:00,  8.04it/s]
# Calculating embeddings: 1it [00:00, 29.66it/s]
# Calculating embeddings: 1it [00:00, 32.46it/s]
# Calculating embeddings: 1it [00:00, 36.72it/s]
# Calculating embeddings: 1it [00:00, 41.41it/s]
# Calculating embeddings: 1it [00:00, 25.01it/s]
# Indexing time (s): 13.8434
# Indexed 54 source files into Milvus.

# %% [markdown]
# ## Build the vector RAG pipeline
#
# The answer-generation logic is aligned with the basic notebook:
# - use only the retrieved context
# - do not invent missing information
# - cite source filenames when possible

# %%
template = [
    ChatMessage.from_user(
        """
Respond to the User Query using only the provided Context.

General Guidelines:
- Use only the provided context.
- If the answer is not found in the context, say so clearly.
- Do not make up facts, document sections, pages, or citations.
- If the answer comes from multiple documents, cite all relevant documents.
- Respond in the same language as the user’s query.
- Do not use emojis.
- Be professional and concise.
- Do not write a conclusion or follow-up unless the user asks for it.
- If the context contains a direct policy rule, exception, SLA, or escalation instruction, state it directly and do not hedge.
- Prefer the most specific procedural source over broader handbook summaries when both are present.
- If the retrieved context does not explicitly contain the rule, exception, owner, or next step needed to answer the question, say that the retrieved context is insufficient instead of inferring or guessing.
- Do not mention system names, tools, workflows, or teams unless they are explicitly present in the retrieved context.

Citation Rules:
- For every important claim, cite the source document filename.
- If available in the retrieved context, also mention the document ID or department.
- Do not mention source chapter, section, or page unless they are explicitly present in the retrieved context.

Context:
{% for document in documents %}
[Source: {{ document.meta.get("file_name", document.meta.get("file_path", "unknown source")) }}]
{{ document.content }}

{% endfor %}

Question: {{question}}
Answer:
"""
    )
]

text_embedder = OpenAITextEmbedder(
    api_key=Secret.from_token(embd_config["VLLM_API_KEY"]),
    api_base_url=f"{embd_config['VLLM_EMBD_URL']}/v1",
    model=embd_config["MODEL_NAME"],
)

retriever = MilvusEmbeddingRetriever(
    document_store=document_store,
    top_k=10
)

chat_generator = OpenAIChatGenerator(
    api_key=Secret.from_token(llm_config["VLLM_API_KEY"]),
    api_base_url=f"{llm_config['VLLM_LLM_URL']}/v1",
    model=llm_config["MODEL_NAME"],
    generation_kwargs={
        "temperature": 0.0,
        "top_p": 1.0,
        "seed": 42,
    }
)

prompt_builder = ChatPromptBuilder(
    template=template,
    required_variables=["question", "documents"]
)

advanced_rag_pipeline = Pipeline()
advanced_rag_pipeline.add_component("text_embedder", text_embedder)
advanced_rag_pipeline.add_component("retriever", retriever)
advanced_rag_pipeline.add_component("prompt_builder", prompt_builder)
advanced_rag_pipeline.add_component("llm", chat_generator)

advanced_rag_pipeline.connect("text_embedder.embedding", "retriever.query_embedding")
advanced_rag_pipeline.connect("retriever.documents", "prompt_builder.documents")
advanced_rag_pipeline.connect("prompt_builder.prompt", "llm.messages")

print("Vector RAG pipeline ready")
# Out:
# Vector RAG pipeline ready

# %% [markdown]
# ## Helper function for presentation queries
#
# The function below:
# - embeds the question
# - retrieves the top document chunks
# - prints the retrieved sources and snippets
# - runs the full vector RAG pipeline
# - prints the final answer

# %%
def run_vectordb_query(question):
    print("=" * 80)
    print("QUESTION:")
    print(question)
    print("=" * 80)

    retrieval_start = time.perf_counter()

    q_emb = text_embedder.run(text=question)["embedding"]
    retr_out = retriever.run(query_embedding=q_emb, top_k=10)
    top_docs = retr_out["documents"]

    retrieval_time_s = round(time.perf_counter() - retrieval_start, 4)

    print(f"\nRETRIEVED DOCUMENTS: {len(top_docs)}")
    print(f"RETRIEVAL TIME (s): {retrieval_time_s}\n")

    for i, d in enumerate(top_docs, 1):
        source = d.meta.get("file_name", d.meta.get("file_path", "unknown source"))
        department = d.meta.get("department", "unknown department")
        snippet = (d.content or "")[:400].replace("\n", " ")
        print(f"[{i}] Source: {source} | Department: {department}")
        print(f"    {snippet}...")
        print()

    generation_start = time.perf_counter()

    result = advanced_rag_pipeline.run({
        "text_embedder": {"text": question},
        "retriever": {"top_k": 10},
        "prompt_builder": {"question": question},
    })

    answer = result["llm"]["replies"][0].text
    generation_time_s = round(time.perf_counter() - generation_start, 4)

    print("=" * 80)
    print("FINAL ANSWER:")
    print("=" * 80)
    print(answer)
    print(f"\nGENERATION TIME (s): {generation_time_s}")

    return top_docs, answer, retrieval_time_s, generation_time_s

# %% [markdown]
# # Saving results in CSV

# %%
def run_and_save_vectordb(question, scenario_id):
    top_docs, answer, retrieval_time_s, generation_time_s = run_vectordb_query(question)

    save_result_row(
        implementation="vectordb",
        scenario_id=scenario_id,
        question=question,
        generated_answer=answer,
        top_docs=top_docs,
        retriever_top_k=10,
        reranker_top_k=None,
        indexing_time_s=indexing_time_s,
        retrieval_time_s=retrieval_time_s,
        generation_time_s=generation_time_s,
        results_csv=RESULTS_CSV,
    )

    return top_docs, answer

# %% [markdown]
# ### Clear vectordb rows

# %%
clear_results_for_implementation("vectordb", results_csv=RESULTS_CSV)
# Out:
# Cleared existing rows for implementation='vectordb'
# PosixPath('/nvme/h/cy26nk2/Thesis/data/results/experimental/hpc_results.csv')

# %% [markdown]
# ### Scenario 1 — Basic fact retrieval
# This is the clean baseline. It shows whether the system can retrieve one exact operational fact correctly.
# - Single-document, single-fact retrieval.
# - Tests basic embedding-based retrieval accuracy.
# - Expected answer should come from the Customer Success / Support materials.

# %%
top_docs_vectordb_s1, answer_vectordb_s1 = run_and_save_vectordb(
    'What is the first-response SLA for a Sev-1 support incident?',
    scenario_id="v1",
)
# Out:
# ================================================================================
# QUESTION:
# What is the first-response SLA for a Sev-1 support incident?
# ================================================================================
#
# RETRIEVED DOCUMENTS: 10
# RETRIEVAL TIME (s): 0.2864
#
# [1] Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx | Department: Q&A Hanbooks
#     Customer Success and Support Handbook Service targets and escalation guide Sev-1 first response, **Target** = 15 min. Sev-1 first response, **Reviewed by** = Support manager. Sev-1 first response, **Notes** = Clock starts when the case is correctly classified. Sev-2 first response, **Target** = 1 hour. Sev-2 first response, **Reviewed by** = Support manager. Sev-2 first response, **Notes** = Inclu...
#
# [2] Source: VAL-CS-001_Severity_Matrix.docx | Department: Customer Support
#     Severity Matrix Classification rules Sev-1, **Typical condition** = Critical production outage at one or more active sites. Sev-1, **Examples** = Pick-path execution blocked, gateway fleet offline, order waves cannot be released. Sev-1, **Response target** = 15 minutes. Sev-1, **Escalate to** = Support manager, Engineering incident lead, CSM. Sev-2, **Typical condition** = Major degradation with n...
#
# [3] Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx | Department: Q&A Hanbooks
#     Customer Success and Support Handbook Specialised Q&A **Q: Who owns customer communication during a Sev-1 incident?** **A:** The assigned support lead owns the operational updates, but the Customer Success Manager owns stakeholder alignment and executive communication. If the issue touches release risk or hardware failure, Engineering or Logistics may join the bridge. **Q: What is the target first...
#
# [4] Source: VAL-CS-001_Severity_Matrix.docx | Department: Customer Support
#     scanner sync failure, dashboard data delayed during active operations. Sev-2, **Response target** = 1 hour. Sev-2, **Escalate to** = Support manager and product duty lead. Sev-3, **Typical condition** = Localized issue or time-sensitive operational question. Sev-3, **Examples** = Role-based permission mismatch, report export issue, integration retry error. Sev-3, **Response target** = 4 business h...
#
# [5] Source: VAL-ENG-001_Release_Freeze_Notice.docx | Department: Engineering
#     Release Freeze Notice Approval path for freeze exceptions Sev-1 production outage, **Status** = Permitted with emergency approval. Sev-1 production outage, **Approver** = Incident Commander + Director of Platform Delivery. Sev-1 production outage, **Required evidence** = Rollback plan and post-incident review required. Critical security remediation, **Status** = Permitted with security approval. C...
#
# [6] Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx | Department: Q&A Hanbooks
#     that hardware shipment dates are realistic. **Q: How are support severities defined?** **A:** Severity is tied to operational impact. Sev-1 means a critical warehouse process cannot run in production. Sev-2 means a major function is degraded with no acceptable workaround. Sev-3 covers localized defects or time-sensitive questions. Sev-4 is low-impact guidance or enhancement clarification....
#
# [7] Source: VAL-CS-004_Renewal_Risk_Signals_Brief.docx | Department: Customer Support
#     Renewal Risk Signals Brief Primary risk signals Repeated Sev-1/Sev-2 incidents, **Why it matters** = Operational trust erodes quickly when warehouse work is repeatedly disrupted.. Repeated Sev-1/Sev-2 incidents, **Review threshold** = 2 or more major incidents in 90 days. Repeated Sev-1/Sev-2 incidents, **Typical action** = Open recovery plan and executive review. Declining adoption of core workfl...
#
# [8] Source: TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx | Department: Q&A Hanbooks
#     Priority and SLA Reference P1, **Typical Example** = Site-wide outage, identity lockout for warehouse shift, executive meeting room failure during customer event. P1, **First Response** = 15 minutes. P1, **Resolution Target** = 4 hours or managed workaround. P2, **Typical Example** = Department-level issue, degraded VPN, multiple device enrollment failures. P2, **First Response** = 30 minutes. P2,...
#
# [9] Source: VAL-CS-001_Severity_Matrix.docx | Department: Customer Support
#     Severity Matrix Classification rules clarification. Sev-4, **Response target** = 1 business day. Sev-4, **Escalate to** = Normal queue management only...
#
# [10] Source: TEAMQA-ENG-001_OrchestrAI_Engineering_Platform_and_Edge_Systems_Handbook.docx | Department: Q&A Hanbooks
#     Edge package rollout, **Target response** = Same-day readiness review. Edge package rollout, **Cross-functional coordination** = Coordinate with Logistics for warehouse maintenance windows.. SEV-1 incident, **Required engineering action** = Assign incident commander, freeze unrelated deploys, and produce a mitigation path.. SEV-1 incident, **Target response** = Within 10 min. SEV-1 incident, **Cro...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# The first-response SLA for a Sev-1 support incident is 15 minutes.
#
# [Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx]
# [Source: VAL-CS-001_Severity_Matrix.docx]
#
# GENERATION TIME (s): 1.249
# Saved result in /nvme/h/cy26nk2/Thesis/data/results/experimental/hpc_results.csv

# %% [markdown]
# ### Scenario 2 — Procedural retrieval
# This scenario is more complex because the answer is not a single fact, but a short operational process.
# - Procedure and checklist retrieval.
# - Tests whether the system can retrieve and summarize structured steps clearly.
# - Expected answer should come mainly from the HR / People Operations materials.

# %%
top_docs_vectordb_s2, answer_vectordb_s2 = run_and_save_vectordb(
    'What steps must be completed before a new employee is considered ready for day one at OrchestrAI?',
    scenario_id="v2",
)
# Out:
# ================================================================================
# QUESTION:
# What steps must be completed before a new employee is considered ready for day one at OrchestrAI?
# ================================================================================
#
# RETRIEVED DOCUMENTS: 10
# RETRIEVAL TIME (s): 0.2854
#
# [1] Source: VAL-HR-001_Day_One_Onboarding_Checklist.docx | Department: HR
#     Day-One Onboarding Checklist **Document ID:** VAL-HR-001 **Owner:** HR & People Operations **Confidentiality:** Internal Use Only Purpose: This checklist standardizes the minimum tasks that must be complete before an OrchestrAI employee can be considered ready for day-one onboarding. **Department**, **Value** = HR & People Operations. **Effective date**, **Value** = 2026-02-24. **Applies to**, **V...
#
# [2] Source: VAL-PROD-001_Launch_Readiness_Checklist.docx | Department: Product
#     **OrchestrAI Team Knowledge Base** **Launch Readiness Checklist** Operational checklist used by Product and PMO to confirm whether a customer-facing release may proceed to go-live. **Effective Date** 2026-03-24, **Department** Product & Program Management = **Review Cycle** Quarterly. **Effective Date** 2026-03-24, **Owner** Program Management Office = **Audience** PMO, Product, Engineering, Suppo...
#
# [3] Source: VAL-PROD-001_Launch_Readiness_Checklist.docx | Department: Product
#     for every OrchestrAI cloud release, edge-firmware rollout, and hardware-adjacent launch where customer communication, support preparation, or operational readiness must be confirmed before go-live. **Readiness gate rules** A release is considered ready only when all mandatory items are marked Complete, every conditional item has either been completed or formally waived, and the launch owner has re...
#
# [4] Source: TEAMQA-HR-001_OrchestrAI_HR_and_People_Operations_Handbook.docx | Department: Q&A Hanbooks
#     HR and People Operations Handbook Specialised Q&A **Q: What does HR and People Operations own at OrchestrAI?** **A:** The team owns employee record quality, onboarding coordination, policy communication, leave administration, manager guidance, workplace process alignment, and lifecycle-event execution. Sensitive employment matters may involve leadership or legal review, but People Ops remains the ...
#
# [5] Source: VAL-FIN-003_Vendor_Onboarding_Requirements.docx | Department: Finance
#     Vendor Onboarding Requirements **Document ID:** VAL-FIN-003 **Owner:** Procurement Operations **Confidentiality:** Internal Use Only Purpose: This document lists the minimum requirements that must be satisfied before a new supplier can be activated for purchasing or payment in OrchestrAI systems. **Effective date**, **Value** = 2026-03-06. **Applies to**, **Value** = New suppliers and reactivated ...
#
# [6] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     the onboarding workflow, which syncs into AtlasDesk after the employee record is created. IT does not build a device against informal chat messages or spreadsheet lists. **Q: What information is required before IT can stage a device?** A: IT needs the employee name, manager, office or shipping location, employment type, start date, preferred platform when policy allows, cost center, and any approv...
#
# [7] Source: VAL-PROD-002_Change_Request_Workflow.docx | Department: Product
#     **OrchestrAI Team Knowledge Base** **Change Request Workflow** Workflow standard for evaluating scope, date, and dependency changes affecting committed OrchestrAI roadmap items or release targets. **Effective Date** 2026-03-24, **Department** Product & Program Management = **Review Cycle** Quarterly. **Effective Date** 2026-03-24, **Owner** PMO Governance Lead = **Audience** PMO, Product, Engineer...
#
# [8] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     = **Related Docs**. **Primary Systems**, IT Workplace Services = TEAMQA-IT-001; VAL-IT-002 **Purpose.** This FAQ explains how OrchestrAI provisions standard corporate laptops for new hires, internal transfers, refresh cycles, and replacement requests. It is written for employees, hiring managers, and local site coordinators who need quick answers about request timing, approvals, imaging, asset tag...
#
# [9] Source: TEAMQA-HR-001_OrchestrAI_HR_and_People_Operations_Handbook.docx | Department: Q&A Hanbooks
#     HR and People Operations Handbook **Document ID:** TEAMQA-HR-001 **Department:** HR & People Operations **Confidentiality:** Internal Use Only **Effective date**, Director, People Operations = 2026-02-24. **Effective date**, **Version** = **Review date**. **Effective date**, 1.0 = 2026-08-24. **Primary systems**, Director, People Operations = PeopleCore, AccessHub, AtlasCRM HR workspace. **Primary...
#
# [10] Source: VAL-HR-002_Leave_Request_Policy_Update.docx | Department: HR
#     Leave Request Policy Update **Document ID:** VAL-HR-002 **Owner:** HR & People Operations **Confidentiality:** Internal Use Only Summary: This update clarifies submission windows, documentation expectations, and manager responsibilities for standard leave requests across OrchestrAI. **Department**, **Value** = HR & People Operations. **Effective date**, **Value** = 2026-03-01. **Supersedes**, **Va...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# According to the Day-One Onboarding Checklist (VAL-HR-001_Day_One_Onboarding_Checklist.docx), the minimum tasks that must be completed before a new employee is considered ready for day one at OrchestrAI include:
#
# - Required documents are recorded
# - Payroll setup is confirmed
# - IT has completed core access and device delivery
# - Orientation is completed
#
# These tasks are outlined in the HR and People Operations Handbook (TEAMQA-HR-001_OrchestrAI_HR_and_People_Operations_Handbook.docx) as well.
#
# GENERATION TIME (s): 2.076
# Saved result in /nvme/h/cy26nk2/Thesis/data/results/experimental/hpc_results.csv

# %% [markdown]
# ### Scenario 3 — Multi-team operational reasoning
# This scenario requires combining information from more than one team to answer a realistic workplace problem.
# - Multi-document, cross-team retrieval.
# - Tests whether the system can synthesize HR, IT, and Security responsibilities.
# - Expected answer should identify both the involved teams and the next actions.

# %%
top_docs_vectordb_s3, answer_vectordb_s3 = run_and_save_vectordb(
    'A new engineer starts on Monday, but their laptop has not arrived and their required access is still pending. Which teams are involved and what should happen next?',
    scenario_id="v3",
)
# Out:
# ================================================================================
# QUESTION:
# A new engineer starts on Monday, but their laptop has not arrived and their required access is still pending. Which teams are involved and what should happen next?
# ================================================================================
#
# RETRIEVED DOCUMENTS: 10
# RETRIEVAL TIME (s): 0.2789
#
# [1] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     Common Questions **Q: How far in advance should a laptop be requested?** A: Standard new-hire laptop requests should be present in the hiring workflow at least seven business days before the employee start date. International shipments, executive hires, and custom software bundles may require ten to fifteen business days. **Q: Which team starts the request?** A: The request begins with the hiring ...
#
# [2] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     1 business day. Non-standard software or admin rights request, **Primary Owner** = Endpoint Engineering. Non-standard software or admin rights request, **Escalation Trigger** = Security review required before release. Shipment delay or damaged delivery, **Primary Owner** = Regional IT / Logistics. Shipment delay or damaged delivery, **Escalation Trigger** = Escalate when delivery risk affects star...
#
# [3] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     **Scope note:** This document covers standard Windows and macOS employee laptops. Warehouse handhelds, kiosk terminals, and engineering lab devices follow separate fulfillment rules. **Provisioning Timeline Snapshot** Request intake, **Owner** = Hiring manager / HRIS. Request intake, **Typical Target** = Day -10 to -7. Request intake, **Key Output** = Valid hire record and cost center. Device sele...
#
# [4] Source: VAL-HR-001_Day_One_Onboarding_Checklist.docx | Department: HR
#     Day-One Onboarding Checklist Pre-start validation Employee record created in PeopleCore, **Owner** = People Ops. Employee record created in PeopleCore, **Due** = T-5 business days. Employee record created in PeopleCore, **Status notes** = Verify manager, location, and title. Laptop and baseline tools requested, **Owner** = IT. Laptop and baseline tools requested, **Due** = T-5 business days. Lapto...
#
# [5] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     Decision and Escalation Reference Start date within 72 hours and no assigned device, **Primary Owner** = IT Service Desk Lead. Start date within 72 hours and no assigned device, **Escalation Trigger** = Notify hiring manager and regional IT manager. Requested model unavailable in stock, **Primary Owner** = Asset Coordinator. Requested model unavailable in stock, **Escalation Trigger** = Escalate t...
#
# [6] Source: VAL-SEC-002_Privileged_Access_Review_Memo.docx | Department: Security
#     Service accounts are reviewed with the owning team lead and must include a mapped application, rotation schedule, and monitoring owner. **Escalation and due dates** Missing reviewer response, **Initial owner** = Role owner. Missing reviewer response, **Escalate to** = IAM manager. Missing reviewer response, **Target** = 2 business days. Unexplained admin activity, **Initial owner** = Security Oper...
#
# [7] Source: TEAMQA-ENG-001_OrchestrAI_Engineering_Platform_and_Edge_Systems_Handbook.docx | Department: Q&A Hanbooks
#     Engineering. **Version**, Engineering = 1.0. **Effective date**, Engineering = 14 January 2026. **Review date**, Engineering = 14 July 2026. **Confidentiality**, Engineering = Internal - Operational and Technical Reference. **Related systems**, Engineering = Control Plane, Edge Gateway, Device Agent, Event Router, Update Channel, Observability Hub **Document purpose** This document explains team s...
#
# [8] Source: VAL-HR-004_Desk_Move_Notice.docx | Department: HR
#     Desk Move Notice What employees should expect **•** Employees with confirmed desk changes will receive seat assignments one business day before the move. **•** Monitors and fixed accessories should remain at the assigned desk unless instructed otherwise by Workplace. **•** IT will support reconnect issues after 13:00 local time on each move day. **•** Requests for accommodation-sensitive seating s...
#
# [9] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     AtlasDesk within one business day. **Q: What happens if a laptop is not available in local stock?** A: IT allocates the closest approved catalog model when possible. If no standard device is available, the request is escalated to Procurement and the hiring manager is notified of revised delivery timing and fallback options. **Q: Who records the asset tag and serial number?** A: The asset coordinat...
#
# [10] Source: TEAMQA-PROD-001_OrchestrAI_Product_and_Program_Management_Handbook.docx | Department: Q&A Hanbooks
#     verbal-only dependencies are not accepted for committed launches. **Q. What happens if Engineering slips a milestone?** A. Program management logs the slip, re-evaluates critical path impact, updates stakeholders, and triggers a change review if the delay affects committed dates or readiness scope. **Q. Who approves a change to a committed release date?**...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# Based on the provided context, the teams involved in this situation are:
#
# 1. IT Service Desk Lead: As the start date is within 72 hours and no assigned device, the IT Service Desk Lead is the primary owner.
# 2. Hiring Manager: The hiring manager should be notified of the issue, as per the escalation trigger.
# 3. Regional IT Manager: The regional IT manager should also be notified, as per the escalation trigger.
#
# The next steps that should happen are:
#
# 1. The IT Service Desk Lead should notify the hiring manager and regional IT manager of the issue.
# 2. The IT Service Desk Lead should investigate the reason for the delayed laptop delivery and work with the asset coordinator to allocate the closest approved catalog model, if possible.
# 3. If no standard device is available, the request should be escalated to Procurement and the hiring manager should be notified of revised delivery timing and fallback options.
#
# Citation: VAL-IT-001_Laptop_Provisioning_FAQ.docx
#
# GENERATION TIME (s): 3.2055
# Saved result in /nvme/h/cy26nk2/Thesis/data/results/experimental/hpc_results.csv

# %% [markdown]
# ### Scenario 4 — Policy + exception handling
# This scenario checks whether the system can distinguish the normal rule from the emergency exception path.
# - Policy retrieval with exception reasoning.
# - Tests whether the system can identify when a standard workflow may be bypassed.
# - Expected answer should combine Finance / Procurement rules with operational urgency.

# %%
top_docs_vectordb_s4, answer_vectordb_s4 = run_and_save_vectordb(
    'Can OrchestrAI make an urgent hardware purchase without following the normal PO workflow if a warehouse outage is at risk?',
    scenario_id="v4",
)
# Out:
# ================================================================================
# QUESTION:
# Can OrchestrAI make an urgent hardware purchase without following the normal PO workflow if a warehouse outage is at risk?
# ================================================================================
#
# RETRIEVED DOCUMENTS: 10
# RETRIEVAL TIME (s): 0.2785
#
# [1] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     exceptions such as extra memory or licensed software. **Q: Can employees choose any laptop model they want?** A: No. OrchestrAI uses a standard device catalog to keep support, security baselines, and spare stock manageable. Exceptions are limited to approved engineering, executive, accessibility, or regional procurement cases. **Q: What software is installed by default?** A: Every standard laptop ...
#
# [2] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook 2. Team Mission and Operating Context The Logistics and Field Fulfillment team ensures that OrchestrAI hardware and deployment kits move from inbound receiving to customer-ready shipment without losing traceability, asset integrity, or installation timing. The team sits at the boundary between software planning and physical execution: it converts...
#
# [3] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     into actual movement of equipment and materials. At OrchestrAI, the logistics function does not only ship standard hardware. It also supports replacement gateway appliances, calibrated barcode scanners, installation spares, return merchandise authorizations, secure wipe returns, and country-specific documentation needed for cross-border fulfillment. Because of that breadth, the team must maintain ...
#
# [4] Source: TEAMQA-FIN-001_OrchestrAI_Finance_and_Procurement_Handbook.docx | Department: Q&A Hanbooks
#     Finance and Procurement Handbook Specialised Q&A **Q: What does Finance and Procurement own at OrchestrAI?** **A:** The team owns vendor onboarding, purchase-order governance, invoice and payment controls, employee reimbursement policy, budget coordination, and month-end readiness. It is also the main gatekeeper for spend discipline and exception documentation. **Q: When is a purchase order requir...
#
# [5] Source: TEAMQA-FIN-001_OrchestrAI_Finance_and_Procurement_Handbook.docx | Department: Q&A Hanbooks
#     Finance and Procurement Handbook Specialised Q&A **A:** Security review is required when the vendor will access OrchestrAI systems, process internal data, host critical workflows, or support services that create operational or privacy risk. **Q: How are hardware purchases handled differently from software subscriptions?** **A:** Hardware purchases often require receiving confirmation, serial track...
#
# [6] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook 5. Operational Questions and Answers Can engineering request direct shipment from incoming stock before quality checks are complete? No. Incoming stock is not eligible for direct customer dispatch until receiving, count verification, and baseline quality checks are complete. Fast-tracking is possible only after the operations manager explicitly a...
#
# [7] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook 5. Operational Questions and Answers How should urgent replacement units be prioritized? Urgent replacements are prioritized using business impact rather than requester seniority. P1 means a live customer site is degraded or offline; P2 means the site is at operational risk within 24 hours; P3 covers planned swap-outs and non-critical reserves. T...
#
# [8] Source: TEAMQA-ENG-001_OrchestrAI_Engineering_Platform_and_Edge_Systems_Handbook.docx | Department: Q&A Hanbooks
#     production-impacting changes require a linked work item, code review, test evidence, and rollback notes. Schema changes must include a compatibility statement and a migration sequencing plan. Feature flags are preferred when operational risk is non-trivial or customer workflow impact is hard to predict. Any change affecting Edge Gateway or Device Agent behavior must define supported firmware, OS, ...
#
# [9] Source: VAL-SEC-003_Patch_Compliance_Reminder.docx | Department: Security
#     **OrchestrAI Security Advisory** **Patch Compliance Reminder** Infrastructure, endpoint, and edge appliance patching requirements for standard and mission-critical assets **Effective Date** 2026-03-24, **Department** Security = **Review Cycle** Monthly. **Effective Date** 2026-03-24, **Owner** Security Operations = **Audience** IT, Engineering, Field Ops. **Effective Date** 2026-03-24, **Version**...
#
# [10] Source: TEAMQA-FIN-001_OrchestrAI_Finance_and_Procurement_Handbook.docx | Department: Q&A Hanbooks
#     Finance and Procurement Handbook Function scope and operating principles Finance and Procurement at OrchestrAI owns spend controls, purchase-order governance, vendor setup, reimbursement policy administration, month-end readiness, and reporting support for cross-functional teams. The function works closely with Sales on pricing and margin exceptions, with Logistics on hardware purchasing and retur...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# No. According to the OrchestrAI Logistics and Field Fulfillment Handbook, incoming stock is not eligible for direct customer dispatch until receiving, count verification, and baseline quality checks are complete. Fast-tracking is possible only after the operations manager explicitly approves an exception and the approval is captured in the shipment record. [TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx]
#
# GENERATION TIME (s): 1.6262
# Saved result in /nvme/h/cy26nk2/Thesis/data/results/experimental/hpc_results.csv

# %% [markdown]
# ### Scenario 5 — Cross-functional enterprise reasoning
# This is the most complex scenario because it requires cross-functional reasoning across several business units.
# - Multi-hop, multi-document retrieval.
# - Tests whether the system can combine support, product, logistics, and commercial risk signals.
# - Expected answer should identify the teams involved and propose a coordinated next-step plan.

# %%
top_docs_vectordb_s5, answer_vectordb_s5 = run_and_save_vectordb(
    'A customer renewal is at risk because support cases are recurring, a requested feature is still unavailable, and replacement hardware is delayed. What should OrchestrAI do next, and which teams must be involved?',
    scenario_id="v5",
)
# Out:
# ================================================================================
# QUESTION:
# A customer renewal is at risk because support cases are recurring, a requested feature is still unavailable, and replacement hardware is delayed. What should OrchestrAI do next, and which teams must be involved?
# ================================================================================
#
# RETRIEVED DOCUMENTS: 10
# RETRIEVAL TIME (s): 0.2776
#
# [1] Source: TEAMQA-FIN-001_OrchestrAI_Finance_and_Procurement_Handbook.docx | Department: Q&A Hanbooks
#     Finance and Procurement Handbook Specialised Q&A **A:** Security review is required when the vendor will access OrchestrAI systems, process internal data, host critical workflows, or support services that create operational or privacy risk. **Q: How are hardware purchases handled differently from software subscriptions?** **A:** Hardware purchases often require receiving confirmation, serial track...
#
# [2] Source: TEAMQA-ENG-001_OrchestrAI_Engineering_Platform_and_Edge_Systems_Handbook.docx | Department: Q&A Hanbooks
#     production-impacting changes require a linked work item, code review, test evidence, and rollback notes. Schema changes must include a compatibility statement and a migration sequencing plan. Feature flags are preferred when operational risk is non-trivial or customer workflow impact is hard to predict. Any change affecting Edge Gateway or Device Agent behavior must define supported firmware, OS, ...
#
# [3] Source: TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx | Department: Q&A Hanbooks
#     Team Q&A **Q: What does the IT team own at OrchestrAI?** **A:** IT owns end-user computing, collaboration services, ticket triage, endpoint compliance, warehouse device support, and coordination with Security, Engineering, and vendors for shared systems. **Q: How should users request help?** **A:** All support requests should be logged in AtlasDesk unless there is a declared outage or the user can...
#
# [4] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook 5. Operational Questions and Answers What data must be preserved for auditability? At minimum, the team must preserve who requested the movement, who approved it, which serial numbers were involved, when the shipment left the warehouse, which carrier handled it, and what exception decisions were made. Auditability is a first-class requirement bec...
#
# [5] Source: VAL-IT-005_Password_Reset_Escalation_SOP.docx | Department: IT
#     Purpose and scope This standard operating procedure defines how OrchestrAI IT handles password reset requests that cannot be completed through the normal self-service flow. It applies to workforce identity accounts, selected support-managed shared identities, and urgent access restoration cases involving business-critical users. Do not treat a password reset as routine when the request involves an...
#
# [6] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     into actual movement of equipment and materials. At OrchestrAI, the logistics function does not only ship standard hardware. It also supports replacement gateway appliances, calibrated barcode scanners, installation spares, return merchandise authorizations, secure wipe returns, and country-specific documentation needed for cross-border fulfillment. Because of that breadth, the team must maintain ...
#
# [7] Source: TEAMQA-SALES-001_OrchestrAI_Sales_and_Solutions_Handbook.docx | Department: Q&A Hanbooks
#     opportunity has a documented warehouse problem, a credible business sponsor, a timeline that matches operational constraints, a measurable business case, and enough process detail to determine whether OrchestrAI can support the workflow without hidden delivery risk. **Q: When must a Solutions Consultant join a deal?** **A:** A Solutions Consultant must join when the opportunity involves integratio...
#
# [8] Source: VAL-SEC-003_Patch_Compliance_Reminder.docx | Department: Security
#     **OrchestrAI Security Advisory** **Patch Compliance Reminder** Infrastructure, endpoint, and edge appliance patching requirements for standard and mission-critical assets **Effective Date** 2026-03-24, **Department** Security = **Review Cycle** Monthly. **Effective Date** 2026-03-24, **Owner** Security Operations = **Audience** IT, Engineering, Field Ops. **Effective Date** 2026-03-24, **Version**...
#
# [9] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook 2. Team Mission and Operating Context The Logistics and Field Fulfillment team ensures that OrchestrAI hardware and deployment kits move from inbound receiving to customer-ready shipment without losing traceability, asset integrity, or installation timing. The team sits at the boundary between software planning and physical execution: it converts...
#
# [10] Source: VAL-PROD-001_Launch_Readiness_Checklist.docx | Department: Product
#     for every OrchestrAI cloud release, edge-firmware rollout, and hardware-adjacent launch where customer communication, support preparation, or operational readiness must be confirmed before go-live. **Readiness gate rules** A release is considered ready only when all mandatory items are marked Complete, every conditional item has either been completed or formally waived, and the launch owner has re...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# Based on the provided context, the retrieved context is insufficient to determine the exact course of action for the customer renewal at risk. However, it can be inferred that the following teams must be involved:
#
# - Solutions Consultant (from TEAMQA-SALES-001_OrchestrAI_Sales_and_Solutions_Handbook.docx) to assess the technical complexity and potential implementation risks.
# - Logistics and Field Fulfillment team (from TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx) to expedite the replacement hardware delivery.
# - IT team (from TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx) to address the recurring support cases and ensure that the customer's systems are properly supported.
#
# The exact steps to be taken by OrchestrAI are not specified in the provided context.
#
# GENERATION TIME (s): 3.0291
# Saved result in /nvme/h/cy26nk2/Thesis/data/results/experimental/hpc_results.csv
