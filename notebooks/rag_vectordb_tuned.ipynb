# %% [markdown]
# # Vector RAG Pipeline (Tuned) on the OrchestrAI Synthetic Enterprise Corpus
#
# This notebook is a tuned variant of `rag_vectordb.ipynb` with larger chunk sizes to evaluate the impact of chunking parameters on retrieval quality.
#
# Changes compared with the original `rag_vectordb` notebook:
# - `HybridChunker` `max_tokens` increased from **300** to **400**
# - `DocumentSplitter` `split_length` increased from **80** to **200** words
# - `DocumentSplitter` `split_overlap` increased from **20** to **40** words
# - results are saved under `implementation="vectordb_tuned"`
#
# Everything else (questions, prompt, LLM, embedding model, top_k) is identical to isolate the effect of chunking.

# %% [markdown]
# ## What is different from the basic notebook?
#
# ### Basic pipeline
# - direct DOCX conversion
# - simple splitting
# - in-memory document store
# - simpler indexing flow
#
# ### Advanced pipeline
# - richer conversion and chunking
# - persistent vector storage in Milvus
# - more robust source metadata handling
# - a more realistic enterprise-style retrieval pipeline

# %% [markdown]
# ## Environment requirements
#
# This notebook assumes:
# - Python **3.11**
# - Ollama is running locally at `http://localhost:11434`
# - the Ollama embedding model `mxbai-embed-large` is available
# - the Ollama chat model `llama3.1` is available
# - a **Milvus server** is running at `http://localhost:19530`
# - the OrchestrAI corpus is stored under `./dummy_data`
#
# Run the optional install cell once if packages are missing.

# %% [markdown]
# ## Imports and runtime checks

# %%
import sys
import warnings
import time
from pathlib import Path
import requests

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
SRC_DIR = PROJECT_ROOT / "src"

if str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

warnings.filterwarnings("ignore")

print("Python:", sys.executable)
print("Ollama tags status:", requests.get("http://localhost:11434/api/tags").status_code)

import importlib
import results_logger
importlib.reload(results_logger)
from results_logger import save_result_row, clear_results_for_implementation
clear_results_for_implementation("vectordb_tuned")

from haystack import Pipeline
from haystack.dataclasses import ChatMessage
from haystack.components.builders import ChatPromptBuilder
from haystack.components.writers import DocumentWriter
from haystack.components.preprocessors import DocumentSplitter, DocumentCleaner

from milvus_haystack import MilvusDocumentStore
from milvus_haystack.milvus_embedding_retriever import MilvusEmbeddingRetriever

from haystack_integrations.components.embedders.ollama import OllamaDocumentEmbedder, OllamaTextEmbedder
from haystack_integrations.components.generators.ollama import OllamaChatGenerator

from haystack_integrations.components.converters.docling import DoclingConverter
from docling.chunking import HybridChunker

print("Imports work")
# Out:
# Python: /Users/nikos/Thesis/.venv/bin/python
# Ollama tags status: 200
# Cleared existing rows for implementation='vectordb_tuned'
# Imports work

# %% [markdown]
# ## Connect to Milvus
#
# This notebook uses a Milvus server connection rather than Milvus Lite.
# This keeps the advanced notebook aligned with a real vector database deployment.

# %%
document_store = MilvusDocumentStore(
    connection_args={"uri": "http://localhost:19530"},
    drop_old=True,
)

print("Milvus ready")
# Out:
# Milvus ready

# %% [markdown]
# ## Load the OrchestrAI dataset
#
# The corpus is organized by department under `./dummy_data`, and all `.docx` files are loaded recursively.

# %%
DOCUMENTS_DIR = PROJECT_ROOT / "data" / "dummy_data"
FILES = [str(f.resolve()) for f in DOCUMENTS_DIR.rglob("*.docx")]

print("Files found:", len(FILES))
for f in FILES[:10]:
    print("-", Path(f).name)
# Out:
# Files found: 54
# - VAL-SALES-003_Campaign_Approval_Workflow_refreshed.docx
# - VAL-SALES-004_CRM_Field_Governance_Note_refreshed.docx
# - VAL-SALES-005_Discount_Exception_Policy_refreshed.docx
# - VAL-SALES-001_Lead_Routing_Rules_refreshed.docx
# - VAL-SALES-002_Webinar_Launch_Brief_refreshed.docx
# - VAL-SEC-003_Patch_Compliance_Reminder.docx
# - VAL-SEC-004_Data_Retention_Notice.docx
# - VAL-SEC-005_Third_Party_Access_Approval_Standard.docx
# - VAL-SEC-002_Privileged_Access_Review_Memo.docx
# - VAL-SEC-001_Phishing_Alert_Bulletin.docx

# %% [markdown]
# ## Advanced indexing strategy
#
# To make the advanced pipeline reliable, the indexing flow is:
#
# 1. Convert each file with `DoclingConverter`
# 2. Attach explicit source metadata (`file_name`, `file_path`, `department`)
# 3. Apply an additional `DocumentSplitter` before embedding
# 4. Remove metadata fields that Milvus cannot store cleanly
# 5. Generate embeddings with Ollama
# 6. Write the embedded chunks to Milvus
#
# This file-by-file indexing approach fixes the earlier `unknown source` problem during retrieval.

# %%
OLLAMA_EMBED_MODEL = "mxbai-embed-large"
HF_TOKENIZER_ID = "mixedbread-ai/mxbai-embed-large-v1"

converter = DoclingConverter(
    chunker=HybridChunker(
        tokenizer=HF_TOKENIZER_ID,
        max_tokens=400,
    )
)

doc_embedder = OllamaDocumentEmbedder(
    model=OLLAMA_EMBED_MODEL,
    url="http://localhost:11434"
)

writer = DocumentWriter(document_store=document_store)

def normalize_meta(meta):
    cleaned = {}
    for key, value in (meta or {}).items():
        if key == "_split_overlap":
            continue
        if isinstance(value, (str, int, float, bool)) or value is None:
            cleaned[key] = value
        else:
            cleaned[key] = str(value)
    return cleaned

indexing_start = time.perf_counter()

for file_path in FILES:
    file_path = Path(file_path)

    result = converter.run(sources=[file_path])
    converted_docs = result["documents"]

    for doc in converted_docs:
        if doc.meta is None:
            doc.meta = {}
        doc.meta["file_name"] = file_path.name
        doc.meta["file_path"] = str(file_path.resolve())
        doc.meta["department"] = file_path.parent.name

    cleaner = DocumentCleaner()
    cleaned_docs = cleaner.run(documents=converted_docs)["documents"]

    for doc in cleaned_docs:
        if doc.meta is None:
            doc.meta = {}
        doc.meta["file_name"] = file_path.name
        doc.meta["file_path"] = str(file_path.resolve())
        doc.meta["department"] = file_path.parent.name

    splitter = DocumentSplitter(
        split_by="word",
        split_length=200,
        split_overlap=40
    )

    split_docs = splitter.run(documents=cleaned_docs)["documents"]

    for doc in split_docs:
        if doc.meta is None:
            doc.meta = {}
        doc.meta["file_name"] = file_path.name
        doc.meta["file_path"] = str(file_path.resolve())
        doc.meta["department"] = file_path.parent.name
        doc.meta = normalize_meta(doc.meta)

    docs_with_embeddings = doc_embedder.run(split_docs)
    writer.run(documents=docs_with_embeddings["documents"])

indexing_time_s = round(time.perf_counter() - indexing_start, 4)

print("Indexing time (s):", indexing_time_s)
print(f"Indexed {len(FILES)} source files into Milvus.")
# Out:
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  5.67it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  6.44it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  6.63it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.60it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  6.30it/s]
# [transformers] Token indices sequence length is longer than the specified maximum sequence length for this model (589 > 512). Running this sequence through the model will result in indexing errors
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.28it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.63it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.76it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.43it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.98it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.49it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.80it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.96it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.51it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.19it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.92it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.70it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.46it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.80it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.71it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.24it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.04it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.82it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.61it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.79it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  5.26it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.21it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.32it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.25it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.38it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.47it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  4.97it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.65it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.37it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.92it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  3.44it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.24it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  2.82it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.92it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:00<00:00,  1.96it/s]
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.39s/it]
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.16s/it]
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.28s/it]
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.32s/it]
# Calculating embeddings: 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# Indexing time (s): 36.8679
# Indexed 54 source files into Milvus.

# %% [markdown]
# ## Build the vector RAG pipeline
#
# The answer-generation logic is aligned with the basic notebook:
# - use only the retrieved context
# - do not invent missing information
# - cite source filenames when possible

# %%
template = [
    ChatMessage.from_user(
        """
Respond to the User Query using only the provided Context.

General Guidelines:
- Use only the provided context.
- If the answer is not found in the context, say so clearly.
- Do not make up facts, document sections, pages, or citations.
- If the answer comes from multiple documents, cite all relevant documents.
- Respond in the same language as the user’s query.
- Do not use emojis.
- Be professional and concise.
- Do not write a conclusion or follow-up unless the user asks for it.
- If the context contains a direct policy rule, exception, SLA, or escalation instruction, state it directly and do not hedge.
- Prefer the most specific procedural source over broader handbook summaries when both are present.
- If the retrieved context does not explicitly contain the rule, exception, owner, or next step needed to answer the question, say that the retrieved context is insufficient instead of inferring or guessing.
- Do not mention system names, tools, workflows, or teams unless they are explicitly present in the retrieved context.

Citation Rules:
- For every important claim, cite the source document filename.
- If available in the retrieved context, also mention the document ID or department.
- Do not mention source chapter, section, or page unless they are explicitly present in the retrieved context.

Context:
{% for document in documents %}
[Source: {{ document.meta.get("file_name", document.meta.get("file_path", "unknown source")) }}]
{{ document.content }}

{% endfor %}

Question: {{question}}
Answer:
"""
    )
]

text_embedder = OllamaTextEmbedder(
    model=OLLAMA_EMBED_MODEL,
    url="http://localhost:11434"
)

retriever = MilvusEmbeddingRetriever(
    document_store=document_store,
    top_k=10
)

chat_generator = OllamaChatGenerator(
    model="llama3.1",
    url="http://localhost:11434",
    generation_kwargs={
        "temperature": 0.0,
        "top_p": 1.0,
        "seed": 42,
    }
)

prompt_builder = ChatPromptBuilder(
    template=template,
    required_variables=["question", "documents"]
)

advanced_rag_pipeline = Pipeline()
advanced_rag_pipeline.add_component("text_embedder", text_embedder)
advanced_rag_pipeline.add_component("retriever", retriever)
advanced_rag_pipeline.add_component("prompt_builder", prompt_builder)
advanced_rag_pipeline.add_component("llm", chat_generator)

advanced_rag_pipeline.connect("text_embedder.embedding", "retriever.query_embedding")
advanced_rag_pipeline.connect("retriever.documents", "prompt_builder.documents")
advanced_rag_pipeline.connect("prompt_builder.prompt", "llm.messages")

print("Vector RAG pipeline ready")
# Out:
# Vector RAG pipeline ready

# %% [markdown]
# ## Helper function for presentation queries
#
# The function below:
# - embeds the question
# - retrieves the top document chunks
# - prints the retrieved sources and snippets
# - runs the full vector RAG pipeline
# - prints the final answer

# %%
def run_vectordb_query(question):
    print("=" * 80)
    print("QUESTION:")
    print(question)
    print("=" * 80)

    retrieval_start = time.perf_counter()

    q_emb = text_embedder.run(text=question)["embedding"]
    retr_out = retriever.run(query_embedding=q_emb, top_k=10)
    top_docs = retr_out["documents"]

    retrieval_time_s = round(time.perf_counter() - retrieval_start, 4)

    print(f"\nRETRIEVED DOCUMENTS: {len(top_docs)}")
    print(f"RETRIEVAL TIME (s): {retrieval_time_s}\n")

    for i, d in enumerate(top_docs, 1):
        source = d.meta.get("file_name", d.meta.get("file_path", "unknown source"))
        department = d.meta.get("department", "unknown department")
        snippet = (d.content or "")[:400].replace("\n", " ")
        print(f"[{i}] Source: {source} | Department: {department}")
        print(f"    {snippet}...")
        print()

    generation_start = time.perf_counter()

    result = advanced_rag_pipeline.run({
        "text_embedder": {"text": question},
        "retriever": {"top_k": 10},
        "prompt_builder": {"question": question},
    })

    answer = result["llm"]["replies"][0].text
    generation_time_s = round(time.perf_counter() - generation_start, 4)

    print("=" * 80)
    print("FINAL ANSWER:")
    print("=" * 80)
    print(answer)
    print(f"\nGENERATION TIME (s): {generation_time_s}")

    return top_docs, answer, retrieval_time_s, generation_time_s

# %% [markdown]
# # Saving results in CSV

# %%
def run_and_save_vectordb(question, scenario_id):
    top_docs, answer, retrieval_time_s, generation_time_s = run_vectordb_query(question)

    save_result_row(
        implementation="vectordb_tuned",
        scenario_id=scenario_id,
        question=question,
        generated_answer=answer,
        top_docs=top_docs,
        retriever_top_k=10,
        reranker_top_k=None,
        indexing_time_s=indexing_time_s,
        retrieval_time_s=retrieval_time_s,
        generation_time_s=generation_time_s,
    )

    return top_docs, answer

# %% [markdown]
# ### Clear vectordb rows

# %%
clear_results_for_implementation("vectordb_tuned")
# Out:
# Cleared existing rows for implementation='vectordb_tuned'
# PosixPath('/Users/nikos/Thesis/data/results/experimental/rag_results.csv')

# %% [markdown]
# ### Scenario 1 — Basic fact retrieval
# This is the clean baseline. It shows whether the system can retrieve one exact operational fact correctly.
# - Single-document, single-fact retrieval.
# - Tests basic embedding-based retrieval accuracy.
# - Expected answer should come from the Customer Success / Support materials.

# %%
top_docs_vectordb_s1, answer_vectordb_s1 = run_and_save_vectordb(
    'What is the first-response SLA for a Sev-1 support incident?',
    scenario_id="vt1",
)
# Out:
# ================================================================================
# QUESTION:
# What is the first-response SLA for a Sev-1 support incident?
# ================================================================================
#
# RETRIEVED DOCUMENTS: 10
# RETRIEVAL TIME (s): 0.0926
#
# [1] Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx | Department: Q&A Hanbooks
#     defects or time-sensitive questions. Sev-4 is low-impact guidance or enhancement clarification. **Q: Who owns customer communication during a Sev-1 incident?** **A:** The assigned support lead owns the operational updates, but the Customer Success Manager owns stakeholder alignment and executive communication. If the issue touches release risk or hardware failure, Engineering or Logistics may join...
#
# [2] Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx | Department: Q&A Hanbooks
#     Customer Success and Support Handbook Service targets and escalation guide Sev-1 first response, **Target** = 15 min. Sev-1 first response, **Reviewed by** = Support manager. Sev-1 first response, **Notes** = Clock starts when the case is correctly classified. Sev-2 first response, **Target** = 1 hour. Sev-2 first response, **Reviewed by** = Support manager. Sev-2 first response, **Notes** = Inclu...
#
# [3] Source: VAL-CS-001_Severity_Matrix.docx | Department: Customer Support
#     Severity Matrix Classification rules Sev-1, **Typical condition** = Critical production outage at one or more active sites. Sev-1, **Examples** = Pick-path execution blocked, gateway fleet offline, order waves cannot be released. Sev-1, **Response target** = 15 minutes. Sev-1, **Escalate to** = Support manager, Engineering incident lead, CSM. Sev-2, **Typical condition** = Major degradation with n...
#
# [4] Source: VAL-ENG-001_Release_Freeze_Notice.docx | Department: Engineering
#     Release Freeze Notice Approval path for freeze exceptions Sev-1 production outage, **Status** = Permitted with emergency approval. Sev-1 production outage, **Approver** = Incident Commander + Director of Platform Delivery. Sev-1 production outage, **Required evidence** = Rollback plan and post-incident review required. Critical security remediation, **Status** = Permitted with security approval. C...
#
# [5] Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx | Department: Q&A Hanbooks
#     Customer Success and Support Handbook Specialised Q&A **Q: What is the difference between Customer Success and Support at OrchestrAI?** **A:** Customer Success owns adoption, stakeholder alignment, value realization, and renewal readiness. Support owns incident handling, case triage, troubleshooting, and documented resolution. The two functions operate together during go-live, major incidents, and...
#
# [6] Source: TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx | Department: Q&A Hanbooks
#     Priority and SLA Reference P1, **Typical Example** = Site-wide outage, identity lockout for warehouse shift, executive meeting room failure during customer event. P1, **First Response** = 15 minutes. P1, **Resolution Target** = 4 hours or managed workaround. P2, **Typical Example** = Department-level issue, degraded VPN, multiple device enrollment failures. P2, **First Response** = 30 minutes. P2,...
#
# [7] Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx | Department: Q&A Hanbooks
#     Customer Success and Support Handbook Operating workflow Implementation handoff, **Trigger** = Signed deployment plan and stakeholder list received. Implementation handoff, **Primary owner** = Onboarding manager. Implementation handoff, **Outputs** = Success plan, milestone tracker, kickoff agenda. Implementation handoff, **Escalate when** = Site timeline slips more than 5 business days. Go-live s...
#
# [8] Source: TEAMQA-ENG-001_OrchestrAI_Engineering_Platform_and_Edge_Systems_Handbook.docx | Department: Q&A Hanbooks
#     Planned cloud release, **Required engineering action** = Publish release notes, validate dashboards, monitor ring progression, and confirm rollback checkpoint.. Planned cloud release, **Target response** = 30 min pre-check / 2 hr hypercare. Planned cloud release, **Cross-functional coordination** = Notify Product, Support, and SRE.. Edge package rollout, **Required engineering action** = Verify ch...
#
# [9] Source: TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx | Department: Q&A Hanbooks
#     Standard Service Workflow 1, **Action** = Log incident or request in AtlasDesk with user, site, asset, and business impact.. 1, **Primary Actor** = Requester / Service Desk. 1, **Target Time** = Immediate. 1, **Output** = Ticket created with category and priority. 2, **Action** = Validate symptoms, confirm scope, and check for duplicate outages or active advisories.. 2, **Primary Actor** = Triage ...
#
# [10] Source: TEAMQA-SEC-001_OrchestrAI_Cybersecurity_Access_and_Compliance_Handbook.docx | Department: Q&A Hanbooks
#     Security Operations leads the incident bridge for confirmed or suspected security events. Engineering and IT contribute technical remediation, while Product, Legal, and Customer Success are engaged depending on customer impact and contractual obligations. Q8. What is the difference between a security event and a security incident? A security event is an observable occurrence such as an alert, fail...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# The target first-response SLA for priority cases (Sev-1) is 15 minutes.
#
# [Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx]
#
# Additionally, the Severity Matrix document also confirms this:
# "Sev-1, **Response target** = 15 minutes."
#
# [Source: VAL-CS-001_Severity_Matrix.docx]
#
# GENERATION TIME (s): 27.4223
# Saved result in /Users/nikos/Thesis/data/results/experimental/rag_results.csv

# %% [markdown]
# ### Scenario 2 — Procedural retrieval
# This scenario is more complex because the answer is not a single fact, but a short operational process.
# - Procedure and checklist retrieval.
# - Tests whether the system can retrieve and summarize structured steps clearly.
# - Expected answer should come mainly from the HR / People Operations materials.

# %%
top_docs_vectordb_s2, answer_vectordb_s2 = run_and_save_vectordb(
    'What steps must be completed before a new employee is considered ready for day one at OrchestrAI?',
    scenario_id="vt2",
)
# Out:
# ================================================================================
# QUESTION:
# What steps must be completed before a new employee is considered ready for day one at OrchestrAI?
# ================================================================================
#
# RETRIEVED DOCUMENTS: 10
# RETRIEVAL TIME (s): 0.0685
#
# [1] Source: VAL-HR-001_Day_One_Onboarding_Checklist.docx | Department: HR
#     Day-One Onboarding Checklist **Document ID:** VAL-HR-001 **Owner:** HR & People Operations **Confidentiality:** Internal Use Only Purpose: This checklist standardizes the minimum tasks that must be complete before an OrchestrAI employee can be considered ready for day-one onboarding. **Department**, **Value** = HR & People Operations. **Effective date**, **Value** = 2026-02-24. **Applies to**, **V...
#
# [2] Source: TEAMQA-HR-001_OrchestrAI_HR_and_People_Operations_Handbook.docx | Department: Q&A Hanbooks
#     HR and People Operations Handbook Specialised Q&A **Q: What does HR and People Operations own at OrchestrAI?** **A:** The team owns employee record quality, onboarding coordination, policy communication, leave administration, manager guidance, workplace process alignment, and lifecycle-event execution. Sensitive employment matters may involve leadership or legal review, but People Ops remains the ...
#
# [3] Source: VAL-HR-001_Day_One_Onboarding_Checklist.docx | Department: HR
#     Day-One Onboarding Checklist Day-one completion rules **•** The new hire must be able to sign in with baseline credentials and MFA. **•** Payroll and tax forms must be complete or formally escalated. **•** The manager must confirm first-week priorities and required meetings. **•** Any missing prerequisite that affects security, payroll, or access must be escalated the same day. Search anchors: onb...
#
# [4] Source: VAL-HR-001_Day_One_Onboarding_Checklist.docx | Department: HR
#     Day-One Onboarding Checklist Pre-start validation Employee record created in PeopleCore, **Owner** = People Ops. Employee record created in PeopleCore, **Due** = T-5 business days. Employee record created in PeopleCore, **Status notes** = Verify manager, location, and title. Laptop and baseline tools requested, **Owner** = IT. Laptop and baseline tools requested, **Due** = T-5 business days. Lapto...
#
# [5] Source: VAL-CS-002_New_Customer_Onboarding_Timeline.docx | Department: Customer Support
#     New Customer Onboarding Timeline **Document ID:** VAL-CS-002 **Department:** Customer Success & Support **Confidentiality:** Internal Use Only **Effective date**, Manager, Implementation Success = 2026-02-10. **Effective date**, **Document type** = **Review date**. **Effective date**, Timeline brief = 2026-08-10 Purpose: Summarizes the standard onboarding timeline used for new OrchestrAI warehouse...
#
# [6] Source: TEAMQA-HR-001_OrchestrAI_HR_and_People_Operations_Handbook.docx | Department: Q&A Hanbooks
#     HR and People Operations Handbook Function scope and operating principles HR and People Operations at OrchestrAI owns the employee record, onboarding coordination, manager guidance, leave administration, policy communication, and workplace-process alignment. The team does not work in isolation: IT provisions devices and accounts, Security applies access controls, Finance supports payroll and expen...
#
# [7] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     Common Questions **Q: How far in advance should a laptop be requested?** A: Standard new-hire laptop requests should be present in the hiring workflow at least seven business days before the employee start date. International shipments, executive hires, and custom software bundles may require ten to fifteen business days. **Q: Which team starts the request?** A: The request begins with the hiring ...
#
# [8] Source: VAL-FIN-003_Vendor_Onboarding_Requirements.docx | Department: Finance
#     Vendor Onboarding Requirements **Document ID:** VAL-FIN-003 **Owner:** Procurement Operations **Confidentiality:** Internal Use Only Purpose: This document lists the minimum requirements that must be satisfied before a new supplier can be activated for purchasing or payment in OrchestrAI systems. **Effective date**, **Value** = 2026-03-06. **Applies to**, **Value** = New suppliers and reactivated ...
#
# [9] Source: VAL-PROD-001_Launch_Readiness_Checklist.docx | Department: Product
#     **OrchestrAI Team Knowledge Base** **Launch Readiness Checklist** Operational checklist used by Product and PMO to confirm whether a customer-facing release may proceed to go-live. **Effective Date** 2026-03-24, **Department** Product & Program Management = **Review Cycle** Quarterly. **Effective Date** 2026-03-24, **Owner** Program Management Office = **Audience** PMO, Product, Engineering, Suppo...
#
# [10] Source: TEAMQA-HR-001_OrchestrAI_HR_and_People_Operations_Handbook.docx | Department: Q&A Hanbooks
#     HR and People Operations Handbook Standard employee-lifecycle workflow Preboarding, **Trigger** = Offer accepted and start date confirmed. Preboarding, **Primary owner** = People Ops coordinator. Preboarding, **Required outputs** = Employee record, onboarding checklist, partner tickets. Preboarding, **Escalate when** = Background docs or approvals are missing. Day-one onboarding, **Trigger** = Emp...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# According to the Day-One Onboarding Checklist (VAL-HR-001), a new hire is considered onboarding-complete after the following tasks are completed:
#
# 1. The new hire must be able to sign in with baseline credentials and MFA.
# 2. Payroll and tax forms must be complete or formally escalated.
# 3. The manager must confirm first-week priorities and required meetings.
# 4. Any missing prerequisite that affects security, payroll, or access must be escalated the same day.
#
# Additionally, the HR and People Operations Handbook (TEAMQA-HR-001) states that a new hire is considered onboarding-complete after required documents are recorded, payroll setup is confirmed, IT has completed core access and device delivery, orientation tasks are finished, and the hiring manager has acknowledged the role-specific ramp plan.
#
# GENERATION TIME (s): 30.762
# Saved result in /Users/nikos/Thesis/data/results/experimental/rag_results.csv

# %% [markdown]
# ### Scenario 3 — Multi-team operational reasoning
# This scenario requires combining information from more than one team to answer a realistic workplace problem.
# - Multi-document, cross-team retrieval.
# - Tests whether the system can synthesize HR, IT, and Security responsibilities.
# - Expected answer should identify both the involved teams and the next actions.

# %%
top_docs_vectordb_s3, answer_vectordb_s3 = run_and_save_vectordb(
    'A new engineer starts on Monday, but their laptop has not arrived and their required access is still pending. Which teams are involved and what should happen next?',
    scenario_id="vt3",
)
# Out:
# ================================================================================
# QUESTION:
# A new engineer starts on Monday, but their laptop has not arrived and their required access is still pending. Which teams are involved and what should happen next?
# ================================================================================
#
# RETRIEVED DOCUMENTS: 10
# RETRIEVAL TIME (s): 0.2059
#
# [1] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     Common Questions **Q: How far in advance should a laptop be requested?** A: Standard new-hire laptop requests should be present in the hiring workflow at least seven business days before the employee start date. International shipments, executive hires, and custom software bundles may require ten to fifteen business days. **Q: Which team starts the request?** A: The request begins with the hiring ...
#
# [2] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     Common Questions **Q: What happens if a laptop is not available in local stock?** A: IT allocates the closest approved catalog model when possible. If no standard device is available, the request is escalated to Procurement and the hiring manager is notified of revised delivery timing and fallback options. **Q: Who records the asset tag and serial number?** A: The asset coordinator records both va...
#
# [3] Source: VAL-HR-001_Day_One_Onboarding_Checklist.docx | Department: HR
#     Day-One Onboarding Checklist Pre-start validation Employee record created in PeopleCore, **Owner** = People Ops. Employee record created in PeopleCore, **Due** = T-5 business days. Employee record created in PeopleCore, **Status notes** = Verify manager, location, and title. Laptop and baseline tools requested, **Owner** = IT. Laptop and baseline tools requested, **Due** = T-5 business days. Lapto...
#
# [4] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     Decision and Escalation Reference Start date within 72 hours and no assigned device, **Primary Owner** = IT Service Desk Lead. Start date within 72 hours and no assigned device, **Escalation Trigger** = Notify hiring manager and regional IT manager. Requested model unavailable in stock, **Primary Owner** = Asset Coordinator. Requested model unavailable in stock, **Escalation Trigger** = Escalate t...
#
# [5] Source: TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx | Department: Q&A Hanbooks
#     Team Q&A **Q: When should IT escalate to Engineering?** **A:** Escalation to Engineering is required when the symptom suggests an application defect, API dependency failure, authentication integration bug, or telemetry issue beyond IT-managed infrastructure. **Q: When should IT escalate to Security?** **A:** Security should be engaged for phishing, suspicious login activity, lost devices with sens...
#
# [6] Source: TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx | Department: Q&A Hanbooks
#     Team Q&A **A:** IT receives an approved hire record, prepares account and hardware based on role profile, verifies MFA enrollment, and confirms access to core collaboration and productivity tools before start date. **Q: What is the offboarding expectation?** **A:** Offboarding actions must begin as soon as HR confirms separation timing. Accounts, devices, badges, and shared mailbox ownership shoul...
#
# [7] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     or regional procurement cases. **Q: What software is installed by default?** A: Every standard laptop is enrolled in FleetPulse, encrypted, linked to AccessHub, and delivered with collaboration tools, browser baseline, endpoint protection, VPN client, password manager, and approved productivity software. **Q: When is manager approval needed?** A: Manager approval is required for non-standard hardw...
#
# [8] Source: TEAMQA-PROD-001_OrchestrAI_Product_and_Program_Management_Handbook.docx | Department: Q&A Hanbooks
#     A. Dependencies should identify the upstream owner, required deliverable, due date, risk if missed, and contingency plan. Hidden or verbal-only dependencies are not accepted for committed launches. **Q. What happens if Engineering slips a milestone?** A. Program management logs the slip, re-evaluates critical path impact, updates stakeholders, and triggers a change review if the delay affects comm...
#
# [9] Source: VAL-IT-001_Laptop_Provisioning_FAQ.docx | Department: IT
#     **OrchestrAI** **Laptop Provisioning FAQ** *IT Workplace Services • Validation Reference • Version 1.0* **Owner**, VAL-IT-001 = Endpoint Engineering Lead. **Owner**, **Department** = **Confidentiality**. **Owner**, IT Workplace Services = Internal Use Only. **Effective Date**, VAL-IT-001 = 15 March 2026. **Effective Date**, **Department** = **Review Date**. **Effective Date**, IT Workplace Service...
#
# [10] Source: VAL-SEC-003_Patch_Compliance_Reminder.docx | Department: Security
#     **Teams involved** Security Operations, IT Workplace, Platform Engineering, Field Support, **Related systems** SentinelOne, FleetOps Console, AccessHub, Edge Control Plane = **Typical queries** Which systems need patching first? When is a gateway considered overdue?...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# Based on the provided context, it appears that there are multiple teams involved in the process of provisioning laptops for new hires.
#
# According to the VAL-IT-001_Laptop_Provisioning_FAQ.docx document, if a laptop is not available in local stock, IT allocates the closest approved catalog model when possible. If no standard device is available, the request is escalated to Procurement and the hiring manager is notified of revised delivery timing and fallback options.
#
# Additionally, according to the Decision and Escalation Reference section of the same document, if a start date within 72 hours and no assigned device, the Primary Owner is IT Service Desk Lead. The escalation trigger is to notify the hiring manager and regional IT manager.
#
# It seems that there are multiple teams involved in this process: IT (specifically the Service Desk Lead), Procurement, and possibly HR or People Ops for notification purposes.
#
# As for what should happen next, it appears that the IT team should be notified of the issue, and they will likely escalate to Procurement if necessary. The hiring manager should also be informed of the revised delivery timing and fallback options.
#
# However, without more specific information on the current status of the laptop provisioning process for this new engineer, it is difficult to provide a more detailed answer.
#
# GENERATION TIME (s): 40.35
# Saved result in /Users/nikos/Thesis/data/results/experimental/rag_results.csv

# %% [markdown]
# ### Scenario 4 — Policy + exception handling
# This scenario checks whether the system can distinguish the normal rule from the emergency exception path.
# - Policy retrieval with exception reasoning.
# - Tests whether the system can identify when a standard workflow may be bypassed.
# - Expected answer should combine Finance / Procurement rules with operational urgency.

# %%
top_docs_vectordb_s4, answer_vectordb_s4 = run_and_save_vectordb(
    'Can OrchestrAI make an urgent hardware purchase without following the normal PO workflow if a warehouse outage is at risk?',
    scenario_id="vt4",
)
# Out:
# ================================================================================
# QUESTION:
# Can OrchestrAI make an urgent hardware purchase without following the normal PO workflow if a warehouse outage is at risk?
# ================================================================================
#
# RETRIEVED DOCUMENTS: 10
# RETRIEVAL TIME (s): 0.063
#
# [1] Source: TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx | Department: Q&A Hanbooks
#     Team Q&A **Q: What does the IT team own at OrchestrAI?** **A:** IT owns end-user computing, collaboration services, ticket triage, endpoint compliance, warehouse device support, and coordination with Security, Engineering, and vendors for shared systems. **Q: How should users request help?** **A:** All support requests should be logged in AtlasDesk unless there is a declared outage or the user can...
#
# [2] Source: TEAMQA-FIN-001_OrchestrAI_Finance_and_Procurement_Handbook.docx | Department: Q&A Hanbooks
#     Finance and Procurement Handbook Specialised Q&A **Q: What does Finance and Procurement own at OrchestrAI?** **A:** The team owns vendor onboarding, purchase-order governance, invoice and payment controls, employee reimbursement policy, budget coordination, and month-end readiness. It is also the main gatekeeper for spend discipline and exception documentation. **Q: When is a purchase order requir...
#
# [3] Source: VAL-LOG-002_Warehouse_Receiving_Checklist.docx | Department: Logistics
#     OrchestrAI Warehouse Receiving Checklist Document ID: VAL-LOG-002 | Department: Logistics and Field Fulfillment | Classification: Internal Use Owner: Regional Warehouse Operations | Version: 1.0 | Effective Date: 24 March 2026 | Review Date: 24 September 2026 Checklist Trigger, Athens Fulfillment Hub; Rotterdam Transit Hub = Inbound appliance, spare part, or return shipment. Checklist Trigger, Rel...
#
# [4] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook 2. Team Mission and Operating Context The Logistics and Field Fulfillment team ensures that OrchestrAI hardware and deployment kits move from inbound receiving to customer-ready shipment without losing traceability, asset integrity, or installation timing. The team sits at the boundary between software planning and physical execution: it converts...
#
# [5] Source: VAL-FIN-005_Emergency_Procurement_Exception_Memo.docx | Department: Finance
#     Emergency Procurement Exception Memo Exception criteria **•** Delay would create a customer outage, security exposure, or warehouse-operational failure. **•** A standard approval path cannot complete in time to avoid material harm. **•** A named executive or delegated approver accepts accountability for the exception....
#
# [6] Source: VAL-LOG-001_Carrier_Delay_Escalation_Notice.docx | Department: Logistics
#     **ORCHESTRAI** **Carrier Delay Escalation Notice** *Logistics Operations | Validation Document* **Owner**, VAL-LOG-001 = Regional Carrier Operations Lead. **Owner**, **Department** = **Version**. **Owner**, Logistics and Field Fulfillment = 1.0. **Effective Date**, VAL-LOG-001 = 2026-03-24. **Effective Date**, **Department** = **Review Date**. **Effective Date**, Logistics and Field Fulfillment = ...
#
# [7] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook 4. Standard Movement Workflow The table below summarizes the expected control points for standard outbound movement of OrchestrAI deployment kits and replacement units. Demand intake, **Primary owner** = Deployment planner. Demand intake, **System checkpoint** = Approved request in EdgeTrack. Demand intake, **Exit criteria** = Customer site, ship...
#
# [8] Source: TEAMQA-FIN-001_OrchestrAI_Finance_and_Procurement_Handbook.docx | Department: Q&A Hanbooks
#     Finance and Procurement Handbook Function scope and operating principles Finance and Procurement at OrchestrAI owns spend controls, purchase-order governance, vendor setup, reimbursement policy administration, month-end readiness, and reporting support for cross-functional teams. The function works closely with Sales on pricing and margin exceptions, with Logistics on hardware purchasing and retur...
#
# [9] Source: VAL-LOG-005_Reverse_Logistics_Routing_Memo.docx | Department: Logistics
#     **OrchestrAI** **Reverse Logistics Routing Memo** Document ID: VAL-LOG-005 | Department: Logistics and Field Fulfillment | Version: 1.0 | Effective Date: 2026-02-10 Owner: Reverse Logistics Program Office | Confidentiality: Internal Use Only | Review Date: 2026-08-10 Purpose: Clarifies how returned OrchestrAI equipment should be routed after customer pickup, field swap, or failed deployment. Use t...
#
# [10] Source: TEAMQA-LOG-001_OrchestrAI_Logistics_and_Field_Fulfillment_Handbook.docx | Department: Q&A Hanbooks
#     OrchestrAI Logistics and Field Fulfillment Handbook Document ID: TEAMQA-LOG-001 | Department: Logistics and Field Fulfillment | Version: 1.0 Scope: warehouse receiving, outbound orchestration, spare device movement, installation logistics, and exception handling **Purpose.** This handbook answers the most common operational questions raised by logistics coordinators, field deployment planners, war...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# According to the Emergency Procurement Exception Memo (VAL-FIN-005_Emergency_Procurement_Exception_Memo.docx), an exception can be made for emergency procurement when:
#
# * A delay would create a customer outage, security exposure, or warehouse-operational failure.
# * A standard approval path cannot complete in time to avoid material harm.
# * A named executive or delegated approver accepts accountability for the exception.
#
# In this case, if a warehouse outage is at risk due to a lack of hardware, an urgent purchase can be made without following the normal PO workflow. However, it requires acceptance by a named executive or delegated approver and documentation of the business justification for the exception.
#
# GENERATION TIME (s): 30.7551
# Saved result in /Users/nikos/Thesis/data/results/experimental/rag_results.csv

# %% [markdown]
# ### Scenario 5 — Cross-functional enterprise reasoning
# This is the most complex scenario because it requires cross-functional reasoning across several business units.
# - Multi-hop, multi-document retrieval.
# - Tests whether the system can combine support, product, logistics, and commercial risk signals.
# - Expected answer should identify the teams involved and propose a coordinated next-step plan.

# %%
top_docs_vectordb_s5, answer_vectordb_s5 = run_and_save_vectordb(
    'A customer renewal is at risk because support cases are recurring, a requested feature is still unavailable, and replacement hardware is delayed. What should OrchestrAI do next, and which teams must be involved?',
    scenario_id="vt5",
)
# Out:
# ================================================================================
# QUESTION:
# A customer renewal is at risk because support cases are recurring, a requested feature is still unavailable, and replacement hardware is delayed. What should OrchestrAI do next, and which teams must be involved?
# ================================================================================
#
# RETRIEVED DOCUMENTS: 10
# RETRIEVAL TIME (s): 0.0847
#
# [1] Source: TEAMQA-IT-001_OrchestrAI_IT_Workplace_and_Service_Desk_Handbook.docx | Department: Q&A Hanbooks
#     Team Q&A **Q: What does the IT team own at OrchestrAI?** **A:** IT owns end-user computing, collaboration services, ticket triage, endpoint compliance, warehouse device support, and coordination with Security, Engineering, and vendors for shared systems. **Q: How should users request help?** **A:** All support requests should be logged in AtlasDesk unless there is a declared outage or the user can...
#
# [2] Source: VAL-CS-004_Renewal_Risk_Signals_Brief.docx | Department: Customer Support
#     Renewal Risk Signals Brief **Document ID:** VAL-CS-004 **Department:** Customer Success & Support **Confidentiality:** Internal Use Only **Effective date**, Director, Customer Success Operations = 2026-02-10. **Effective date**, **Document type** = **Review date**. **Effective date**, Risk brief = 2026-08-10 Purpose: Defines the most important signals used by OrchestrAI Customer Success teams to i...
#
# [3] Source: VAL-CS-004_Renewal_Risk_Signals_Brief.docx | Department: Customer Support
#     = Sponsor change with no new confirmed owner in 30 days. Stakeholder turnover or executive silence, **Typical action** = Refresh stakeholder map and sponsor plan. Expansion delay or rollback discussion, **Why it matters** = Commercial hesitation often appears before formal renewal objections.. Expansion delay or rollback discussion, **Review threshold** = Expansion paused or customer requests cont...
#
# [4] Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx | Department: Q&A Hanbooks
#     Customer Success and Support Handbook **Document ID:** TEAMQA-CS-001 **Department:** Customer Success & Support **Confidentiality:** Internal Use Only **Effective date**, Director, Customer Success Operations = 2026-02-10. **Effective date**, **Version** = **Review date**. **Effective date**, 1.0 = 2026-08-10. **Primary systems**, Director, Customer Success Operations = PulseDesk, AtlasCRM, Beacon...
#
# [5] Source: VAL-LOG-001_Carrier_Delay_Escalation_Notice.docx | Department: Logistics
#     **ORCHESTRAI** **Carrier Delay Escalation Notice** *Logistics Operations | Validation Document* **Owner**, VAL-LOG-001 = Regional Carrier Operations Lead. **Owner**, **Department** = **Version**. **Owner**, Logistics and Field Fulfillment = 1.0. **Effective Date**, VAL-LOG-001 = 2026-03-24. **Effective Date**, **Department** = **Review Date**. **Effective Date**, Logistics and Field Fulfillment = ...
#
# [6] Source: VAL-ENG-004_Incident_RCA_Event_Processor_Timeout.docx | Department: Engineering
#     **OrchestrAI Engineering Incident RCA** *VAL-ENG-004 | Event Processor Timeout* **Severity**, Engineering Platform = SEV-2. **Severity**, **Owner** = **Status**. **Severity**, Platform Reliability Team = Closed. **Incident Start**, Engineering Platform = 2026-01-14 09:12 UTC. **Incident Start**, **Owner** = **Mitigation Complete**. **Incident Start**, Platform Reliability Team = 2026-01-14 10:26 U...
#
# [7] Source: VAL-SEC-003_Patch_Compliance_Reminder.docx | Department: Security
#     **OrchestrAI Security Advisory** **Patch Compliance Reminder** Infrastructure, endpoint, and edge appliance patching requirements for standard and mission-critical assets **Effective Date** 2026-03-24, **Department** Security = **Review Cycle** Monthly. **Effective Date** 2026-03-24, **Owner** Security Operations = **Audience** IT, Engineering, Field Ops. **Effective Date** 2026-03-24, **Version**...
#
# [8] Source: TEAMQA-CS-001_OrchestrAI_Customer_Success_and_Support_Handbook.docx | Department: Q&A Hanbooks
#     Customer Success and Support Handbook Specialised Q&A **A:** Support involves Engineering when logs indicate a product defect, a recurring incident pattern, an undocumented behavior change after release, or a required fix exceeds configuration workarounds. **Q: How are feature requests handled?** **A:** Feature requests are documented in AtlasCRM with account context, business impact, and urgency....
#
# [9] Source: VAL-ENG-003_API_Deprecation_Notice.docx | Department: Engineering
#     **OrchestrAI Engineering Notice**...
#
# [10] Source: VAL-ENG-001_Release_Freeze_Notice.docx | Department: Engineering
#     **OrchestrAI Engineering Notice**...
#
# ================================================================================
# FINAL ANSWER:
# ================================================================================
# The retrieved context does not explicitly contain the rule or instruction for handling a customer renewal at risk due to recurring support cases, unavailability of a requested feature, and delayed replacement hardware.
#
# However, it mentions that common risk indicators include unresolved critical defects, repeated SLA misses, poor adoption of core workflows, stakeholder turnover, delayed site expansion, and negative executive sentiment. It also states that recovery plans should be structured with the problem statement, impact summary, named owners, short-term mitigation, long-term corrective actions, customer-facing milestones, and the executive update cadence.
#
# Based on this information, OrchestrAI may need to involve multiple teams, including Customer Success, Engineering, and Support, to address these issues. However, the context does not provide a specific instruction or policy for handling such situations.
#
# Therefore, I must state that the retrieved context is insufficient to provide a clear answer to the question.
#
# GENERATION TIME (s): 29.0544
# Saved result in /Users/nikos/Thesis/data/results/experimental/rag_results.csv
